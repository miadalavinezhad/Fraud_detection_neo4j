# %%
import csv

with open("C:/Users/Asus/Documents/University/New-Gen-Project/Scripts/data_sets_50/transaction.csv", 'r') as f:
    reader = csv.reader(f)
    next(reader) # skip header row
    transaction = [row for row in reader]

# %%
from datetime import datetime

# %%
for i, row in enumerate(transaction):
    transaction[i][2] = datetime.strptime(row[2], "%Y-%m-%d %H:%M:%S")

# %%
transaction
# Out:
# [['0',
#   '0',
#   datetime.datetime(2018, 4, 1, 0, 0, 31),
#   '596',
#   '328',
#   '97.61',
#   '31',
#   '0'],
#  ['1',
#   '1',
#   datetime.datetime(2018, 4, 1, 0, 3, 16),
#   '36',
#   '986',
#   '24.31',
#   '196',
#   '0'],
#  ['2',
#   '2',
#   datetime.datetime(2018, 4, 1, 0, 6, 35),
#   '634',
#   '703',
#   '32.17',
#   '395',
#   '0'],
#  ['3',
#   '3',
#   datetime.datetime(2018, 4, 1, 0, 7, 56),
#   '2',
#   '1335',
#   '169.15',
#   '476',
#   '0'],
#  ['4',
#   '4',
#   datetime.datetime(2018, 4, 1, 0, 11, 6),
#   '443',
#   '15',
#   '36.85',
#   '666',
#   '0'],
#  ['5',
#   '5',
#   datetime.datetime(2018, 4, 1, 0, 13, 32),
#   '548',
#   '1047',
#   '64.48',
#   '812',
#   '0'],
#  ['6',
#   '6',
#   datetime.datetime(2018, 4, 1, 0, 15, 26),
#   '639',
#   '58',
#   '43.87',
#   '926',
#   '0'],
#  ['7',
#   '7',
#   datetime.datetime(2018, 4, 1, 0, 19, 20),
#   '890',
#   '1237',
#   '19.29',
#   '1160',
#   '0'],
#  ['8',
#   '8',
#   datetime.datetime(2018, 4, 1, 0, 23, 51),
#   '376',
#   '495',
#   '18.04',
#   '1431',
#   '0'],
#  ['9',
#   '9',
#   datetime.datetime(2018, 4, 1, 0, 25, 3),
#   '541',
#   '375',
#   '31.11',
#   '1503',
#   '0'],
#  ['10',
#   '10',
#   datetime.datetime(2018, 4, 1, 0, 27, 2),
#   '483',
#   '301',
#   '30.31',
#   '1622',
#   '0'],
#  ['11',
#   '11',
#   datetime.datetime(2018, 4, 1, 0, 27, 58),
#   '69',
#   '1199',
#   '88.54',
#   '1678',
#   '0'],
#  ['12',
#   '12',
#   datetime.datetime(2018, 4, 1, 0, 28, 7),
#   '616',
#   '253',
#   '52.54',
#   '1687',
#   '0'],
#  ['13',
#   '13',
#   datetime.datetime(2018, 4, 1, 0, 28, 18),
#   '599',
#   '1672',
#   '107.88',
#   '1698',
#   '0'],
#  ['14',
#   '14',
#   datetime.datetime(2018, 4, 1, 0, 28, 22),
#   '48',
#   '1698',
#   '23.69',
#   '1702',
#   '0'],
#  ['15',
#   '15',
#   datetime.datetime(2018, 4, 1, 0, 29, 8),
#   '479',
#   '726',
#   '23.99',
#   '1748',
#   '0'],
#  ['16',
#   '16',
#   datetime.datetime(2018, 4, 1, 0, 29, 8),
#   '848',
#   '968',
#   '25.22',
#   '1748',
#   '0'],
#  ['17',
#   '17',
#   datetime.datetime(2018, 4, 1, 0, 29, 9),
#   '813',
#   '1036',
#   '92.34',
#   '1749',
#   '0'],
#  ['18',
#   '18',
#   datetime.datetime(2018, 4, 1, 0, 29, 26),
#   '885',
#   '1842',
#   '30.92',
#   '1766',
#   '0'],
#  ['19',
#   '19',
#   datetime.datetime(2018, 4, 1, 0, 29, 46),
#   '437',
#   '532',
#   '65.2',
#   '1786',
#   '0'],
#  ['20',
#   '20',
#   datetime.datetime(2018, 4, 1, 0, 33, 3),
#   '189',
#   '984',
#   '46.85',
#   '1983',
#   '0'],
#  ['21',
#   '21',
#   datetime.datetime(2018, 4, 1, 0, 34, 55),
#   '234',
#   '1488',
#   '75.5',
#   '2095',
#   '0'],
#  ['22',
#   '22',
#   datetime.datetime(2018, 4, 1, 0, 35, 25),
#   '843',
#   '1570',
#   '26.58',
#   '2125',
#   '0'],
#  ['23',
#   '23',
#   datetime.datetime(2018, 4, 1, 0, 35, 26),
#   '140',
#   '47',
#   '3.29',
#   '2126',
#   '0'],
#  ['24',
#   '24',
#   datetime.datetime(2018, 4, 1, 0, 36),
#   '519',
#   '693',
#   '90.01',
#   '2160',
#   '0'],
#  ['25',
#   '25',
#   datetime.datetime(2018, 4, 1, 0, 36, 56),
#   '814',
#   '369',
#   '72.16',
#   '2216',
#   '0'],
#  ['26',
#   '26',
#   datetime.datetime(2018, 4, 1, 0, 36, 56),
#   '661',
#   '1788',
#   '64.56',
#   '2216',
#   '0'],
#  ['27',
#   '27',
#   datetime.datetime(2018, 4, 1, 0, 41, 15),
#   '638',
#   '862',
#   '108.31',
#   '2475',
#   '0'],
#  ['28',
#   '28',
#   datetime.datetime(2018, 4, 1, 0, 41, 41),
#   '473',
#   '497',
#   '57.03',
#   '2501',
#   '0'],
#  ['29',
#   '29',
#   datetime.datetime(2018, 4, 1, 0, 43, 52),
#   '564',
#   '384',
#   '33.31',
#   '2632',
#   '0'],
#  ['30',
#   '30',
#   datetime.datetime(2018, 4, 1, 0, 47, 7),
#   '231',
#   '1664',
#   '18.02',
#   '2827',
#   '0'],
#  ['31',
#   '31',
#   datetime.datetime(2018, 4, 1, 0, 47, 49),
#   '328',
#   '1038',
#   '52.35',
#   '2869',
#   '0'],
#  ['32',
#   '32',
#   datetime.datetime(2018, 4, 1, 0, 49, 40),
#   '206',
#   '1841',
#   '77.06',
#   '2980',
#   '0'],
#  ['33',
#   '33',
#   datetime.datetime(2018, 4, 1, 0, 50, 29),
#   '544',
#   '1991',
#   '91.99',
#   '3029',
#   '0'],
#  ['34',
#   '34',
#   datetime.datetime(2018, 4, 1, 0, 51, 27),
#   '160',
#   '1240',
#   '87.33',
#   '3087',
#   '0'],
#  ['35',
#   '35',
#   datetime.datetime(2018, 4, 1, 0, 52, 55),
#   '4',
#   '79',
#   '6.7',
#   '3175',
#   '0'],
#  ['36',
#   '36',
#   datetime.datetime(2018, 4, 1, 0, 55, 56),
#   '893',
#   '1123',
#   '25.53',
#   '3356',
#   '0'],
#  ['37',
#   '37',
#   datetime.datetime(2018, 4, 1, 0, 57, 42),
#   '815',
#   '1062',
#   '16.61',
#   '3462',
#   '0'],
#  ['38',
#   '38',
#   datetime.datetime(2018, 4, 1, 0, 59, 21),
#   '69',
#   '1588',
#   '24.13',
#   '3561',
#   '0'],
#  ['39',
#   '39',
#   datetime.datetime(2018, 4, 1, 1, 1, 24),
#   '412',
#   '412',
#   '45.87',
#   '3684',
#   '0'],
#  ['40',
#   '40',
#   datetime.datetime(2018, 4, 1, 1, 3, 24),
#   '38',
#   '47',
#   '77.15',
#   '3804',
#   '0'],
#  ['41',
#   '41',
#   datetime.datetime(2018, 4, 1, 1, 5, 24),
#   '204',
#   '403',
#   '38.66',
#   '3924',
#   '0'],
#  ['42',
#   '42',
#   datetime.datetime(2018, 4, 1, 1, 5, 25),
#   '22',
#   '1181',
#   '35.99',
#   '3925',
#   '0'],
#  ['43',
#   '43',
#   datetime.datetime(2018, 4, 1, 1, 6, 38),
#   '860',
#   '541',
#   '91.54',
#   '3998',
#   '0'],
#  ['44',
#   '44',
#   datetime.datetime(2018, 4, 1, 1, 6, 42),
#   '862',
#   '774',
#   '131.59',
#   '4002',
#   '0'],
#  ['45',
#   '45',
#   datetime.datetime(2018, 4, 1, 1, 7, 28),
#   '479',
#   '1852',
#   '37.3',
#   '4048',
#   '0'],
#  ['46',
#   '46',
#   datetime.datetime(2018, 4, 1, 1, 8, 18),
#   '412',
#   '652',
#   '24.32',
#   '4098',
#   '0'],
#  ['47',
#   '47',
#   datetime.datetime(2018, 4, 1, 1, 8, 33),
#   '313',
#   '325',
#   '27.12',
#   '4113',
#   '0'],
#  ['48',
#   '48',
#   datetime.datetime(2018, 4, 1, 1, 10, 12),
#   '875',
#   '257',
#   '137.4',
#   '4212',
#   '0'],
#  ['49',
#   '49',
#   datetime.datetime(2018, 4, 1, 1, 10, 13),
#   '223',
#   '1880',
#   '97.28',
#   '4213',
#   '0'],
#  ['50',
#   '50',
#   datetime.datetime(2018, 4, 1, 1, 11, 49),
#   '536',
#   '54',
#   '23.06',
#   '4309',
#   '0'],
#  ['51',
#   '51',
#   datetime.datetime(2018, 4, 1, 1, 11, 53),
#   '701',
#   '798',
#   '68.98',
#   '4313',
#   '0'],
#  ['52',
#   '52',
#   datetime.datetime(2018, 4, 1, 1, 13, 4),
#   '897',
#   '1116',
#   '89.72',
#   '4384',
#   '0'],
#  ['53',
#   '53',
#   datetime.datetime(2018, 4, 1, 1, 15, 10),
#   '555',
#   '1910',
#   '3.96',
#   '4510',
#   '0'],
#  ['54',
#   '54',
#   datetime.datetime(2018, 4, 1, 1, 15, 16),
#   '280',
#   '1488',
#   '49.75',
#   '4516',
#   '0'],
#  ['55',
#   '55',
#   datetime.datetime(2018, 4, 1, 1, 15, 45),
#   '833',
#   '615',
#   '25.12',
#   '4545',
#   '0'],
#  ['56',
#   '56',
#   datetime.datetime(2018, 4, 1, 1, 15, 53),
#   '36',
#   '429',
#   '29.76',
#   '4553',
#   '0'],
#  ['57',
#   '57',
#   datetime.datetime(2018, 4, 1, 1, 16, 22),
#   '57',
#   '1541',
#   '101.58',
#   '4582',
#   '0'],
#  ['58',
#   '58',
#   datetime.datetime(2018, 4, 1, 1, 16, 36),
#   '525',
#   '1812',
#   '45.62',
#   '4596',
#   '0'],
#  ['59',
#   '59',
#   datetime.datetime(2018, 4, 1, 1, 16, 38),
#   '896',
#   '1944',
#   '57.77',
#   '4598',
#   '0'],
#  ['60',
#   '60',
#   datetime.datetime(2018, 4, 1, 1, 17, 26),
#   '728',
#   '725',
#   '68.06',
#   '4646',
#   '0'],
#  ['61',
#   '61',
#   datetime.datetime(2018, 4, 1, 1, 17, 56),
#   '801',
#   '655',
#   '66.91',
#   '4676',
#   '0'],
#  ['62',
#   '62',
#   datetime.datetime(2018, 4, 1, 1, 18, 19),
#   '181',
#   '1268',
#   '37.28',
#   '4699',
#   '0'],
#  ['63',
#   '63',
#   datetime.datetime(2018, 4, 1, 1, 20, 20),
#   '294',
#   '1936',
#   '34.89',
#   '4820',
#   '0'],
#  ['64',
#   '64',
#   datetime.datetime(2018, 4, 1, 1, 20, 54),
#   '395',
#   '1815',
#   '113.73',
#   '4854',
#   '0'],
#  ['65',
#   '65',
#   datetime.datetime(2018, 4, 1, 1, 22, 16),
#   '852',
#   '1355',
#   '112.91',
#   '4936',
#   '0'],
#  ['66',
#   '66',
#   datetime.datetime(2018, 4, 1, 1, 22, 28),
#   '300',
#   '1603',
#   '15.89',
#   '4948',
#   '0'],
#  ['67',
#   '67',
#   datetime.datetime(2018, 4, 1, 1, 24, 58),
#   '761',
#   '1978',
#   '13.4',
#   '5098',
#   '0'],
#  ['68',
#   '68',
#   datetime.datetime(2018, 4, 1, 1, 25, 16),
#   '363',
#   '1954',
#   '91.69',
#   '5116',
#   '0'],
#  ['69',
#   '69',
#   datetime.datetime(2018, 4, 1, 1, 25, 26),
#   '550',
#   '1128',
#   '22.86',
#   '5126',
#   '0'],
#  ['70',
#   '70',
#   datetime.datetime(2018, 4, 1, 1, 25, 34),
#   '203',
#   '1733',
#   '81.71',
#   '5134',
#   '0'],
#  ['71',
#   '71',
#   datetime.datetime(2018, 4, 1, 1, 26, 30),
#   '677',
#   '1589',
#   '60.65',
#   '5190',
#   '0'],
#  ['72',
#   '72',
#   datetime.datetime(2018, 4, 1, 1, 29, 52),
#   '673',
#   '295',
#   '63.55',
#   '5392',
#   '0'],
#  ['73',
#   '73',
#   datetime.datetime(2018, 4, 1, 1, 30, 13),
#   '144',
#   '238',
#   '169.58',
#   '5413',
#   '0'],
#  ['74',
#   '74',
#   datetime.datetime(2018, 4, 1, 1, 31, 4),
#   '424',
#   '1929',
#   '44.15',
#   '5464',
#   '0'],
#  ['75',
#   '75',
#   datetime.datetime(2018, 4, 1, 1, 32, 18),
#   '510',
#   '126',
#   '74.88',
#   '5538',
#   '0'],
#  ['76',
#   '76',
#   datetime.datetime(2018, 4, 1, 1, 35),
#   '633',
#   '1000',
#   '44.82',
#   '5700',
#   '0'],
#  ['77',
#   '77',
#   datetime.datetime(2018, 4, 1, 1, 35, 50),
#   '588',
#   '536',
#   '15.92',
#   '5750',
#   '0'],
#  ['78',
#   '78',
#   datetime.datetime(2018, 4, 1, 1, 36, 41),
#   '130',
#   '648',
#   '29.79',
#   '5801',
#   '0'],
#  ['79',
#   '79',
#   datetime.datetime(2018, 4, 1, 1, 38, 46),
#   '589',
#   '1361',
#   '12.39',
#   '5926',
#   '0'],
#  ['80',
#   '80',
#   datetime.datetime(2018, 4, 1, 1, 38, 58),
#   '141',
#   '1479',
#   '7.41',
#   '5938',
#   '0'],
#  ['81',
#   '81',
#   datetime.datetime(2018, 4, 1, 1, 39, 5),
#   '709',
#   '1137',
#   '44.84',
#   '5945',
#   '0'],
#  ['82',
#   '82',
#   datetime.datetime(2018, 4, 1, 1, 39, 26),
#   '468',
#   '1007',
#   '65.11',
#   '5966',
#   '0'],
#  ['83',
#   '83',
#   datetime.datetime(2018, 4, 1, 1, 39, 26),
#   '180',
#   '1057',
#   '11.02',
#   '5966',
#   '0'],
#  ['84',
#   '84',
#   datetime.datetime(2018, 4, 1, 1, 41, 12),
#   '581',
#   '1467',
#   '22.7',
#   '6072',
#   '0'],
#  ['85',
#   '85',
#   datetime.datetime(2018, 4, 1, 1, 42, 21),
#   '692',
#   '1656',
#   '131.29',
#   '6141',
#   '0'],
#  ['86',
#   '86',
#   datetime.datetime(2018, 4, 1, 1, 42, 43),
#   '712',
#   '1704',
#   '1.68',
#   '6163',
#   '0'],
#  ['87',
#   '87',
#   datetime.datetime(2018, 4, 1, 1, 43, 7),
#   '192',
#   '542',
#   '35.87',
#   '6187',
#   '0'],
#  ['88',
#   '88',
#   datetime.datetime(2018, 4, 1, 1, 44, 23),
#   '849',
#   '531',
#   '10.14',
#   '6263',
#   '0'],
#  ['89',
#   '89',
#   datetime.datetime(2018, 4, 1, 1, 45, 21),
#   '461',
#   '1000',
#   '89.04',
#   '6321',
#   '0'],
#  ['90',
#   '90',
#   datetime.datetime(2018, 4, 1, 1, 45, 27),
#   '417',
#   '1870',
#   '41.21',
#   '6327',
#   '0'],
#  ['91',
#   '91',
#   datetime.datetime(2018, 4, 1, 1, 45, 31),
#   '50',
#   '697',
#   '98.69',
#   '6331',
#   '0'],
#  ['92',
#   '92',
#   datetime.datetime(2018, 4, 1, 1, 45, 47),
#   '754',
#   '1507',
#   '64.46',
#   '6347',
#   '0'],
#  ['93',
#   '93',
#   datetime.datetime(2018, 4, 1, 1, 47, 9),
#   '584',
#   '261',
#   '6.54',
#   '6429',
#   '0'],
#  ['94',
#   '94',
#   datetime.datetime(2018, 4, 1, 1, 47, 45),
#   '406',
#   '874',
#   '16.95',
#   '6465',
#   '0'],
#  ['95',
#   '95',
#   datetime.datetime(2018, 4, 1, 1, 48, 6),
#   '753',
#   '1380',
#   '9.0',
#   '6486',
#   '0'],
#  ['96',
#   '96',
#   datetime.datetime(2018, 4, 1, 1, 48, 32),
#   '578',
#   '1415',
#   '27.5',
#   '6512',
#   '0'],
#  ['97',
#   '97',
#   datetime.datetime(2018, 4, 1, 1, 49, 36),
#   '348',
#   '956',
#   '128.66',
#   '6576',
#   '0'],
#  ['98',
#   '98',
#   datetime.datetime(2018, 4, 1, 1, 49, 45),
#   '871',
#   '317',
#   '72.68',
#   '6585',
#   '0'],
#  ['99',
#   '99',
#   datetime.datetime(2018, 4, 1, 1, 51),
#   '197',
#   '1432',
#   '27.92',
#   '6660',
#   '0'],
#  ['100',
#   '100',
#   datetime.datetime(2018, 4, 1, 1, 51, 39),
#   '269',
#   '279',
#   '60.38',
#   '6699',
#   '0'],
#  ['101',
#   '101',
#   datetime.datetime(2018, 4, 1, 1, 51, 49),
#   '484',
#   '562',
#   '101.84',
#   '6709',
#   '0'],
#  ['102',
#   '102',
#   datetime.datetime(2018, 4, 1, 1, 52, 6),
#   '709',
#   '1928',
#   '2.55',
#   '6726',
#   '0'],
#  ['103',
#   '103',
#   datetime.datetime(2018, 4, 1, 1, 52, 47),
#   '478',
#   '921',
#   '5.91',
#   '6767',
#   '0'],
#  ['104',
#   '104',
#   datetime.datetime(2018, 4, 1, 1, 52, 52),
#   '475',
#   '712',
#   '25.64',
#   '6772',
#   '0'],
#  ['105',
#   '105',
#   datetime.datetime(2018, 4, 1, 1, 53, 3),
#   '605',
#   '1513',
#   '85.74',
#   '6783',
#   '0'],
#  ['106',
#   '106',
#   datetime.datetime(2018, 4, 1, 1, 53, 10),
#   '668',
#   '316',
#   '30.94',
#   '6790',
#   '0'],
#  ['107',
#   '107',
#   datetime.datetime(2018, 4, 1, 1, 54, 44),
#   '419',
#   '632',
#   '57.42',
#   '6884',
#   '0'],
#  ['108',
#   '108',
#   datetime.datetime(2018, 4, 1, 1, 55, 28),
#   '631',
#   '138',
#   '26.07',
#   '6928',
#   '0'],
#  ['109',
#   '109',
#   datetime.datetime(2018, 4, 1, 1, 55, 30),
#   '262',
#   '567',
#   '1.51',
#   '6930',
#   '0'],
#  ['110',
#   '110',
#   datetime.datetime(2018, 4, 1, 1, 55, 54),
#   '598',
#   '570',
#   '94.95',
#   '6954',
#   '0'],
#  ['111',
#   '111',
#   datetime.datetime(2018, 4, 1, 1, 56, 44),
#   '55',
#   '1964',
#   '73.41',
#   '7004',
#   '0'],
#  ['112',
#   '112',
#   datetime.datetime(2018, 4, 1, 1, 57, 43),
#   '470',
#   '301',
#   '13.26',
#   '7063',
#   '0'],
#  ['113',
#   '113',
#   datetime.datetime(2018, 4, 1, 1, 59),
#   '203',
#   '889',
#   '72.44',
#   '7140',
#   '0'],
#  ['114',
#   '114',
#   datetime.datetime(2018, 4, 1, 1, 59, 40),
#   '223',
#   '80',
#   '120.44',
#   '7180',
#   '0'],
#  ['115',
#   '115',
#   datetime.datetime(2018, 4, 1, 2, 0, 46),
#   '331',
#   '467',
#   '91.8',
#   '7246',
#   '0'],
#  ['116',
#   '116',
#   datetime.datetime(2018, 4, 1, 2, 1, 32),
#   '570',
#   '562',
#   '6.08',
#   '7292',
#   '0'],
#  ['117',
#   '117',
#   datetime.datetime(2018, 4, 1, 2, 2, 22),
#   '761',
#   '1210',
#   '11.27',
#   '7342',
#   '0'],
#  ['118',
#   '118',
#   datetime.datetime(2018, 4, 1, 2, 2, 29),
#   '285',
#   '787',
#   '49.83',
#   '7349',
#   '0'],
#  ['119',
#   '119',
#   datetime.datetime(2018, 4, 1, 2, 2, 44),
#   '309',
#   '877',
#   '30.74',
#   '7364',
#   '0'],
#  ['120',
#   '120',
#   datetime.datetime(2018, 4, 1, 2, 3, 55),
#   '41',
#   '1240',
#   '31.74',
#   '7435',
#   '0'],
#  ['121',
#   '121',
#   datetime.datetime(2018, 4, 1, 2, 4, 47),
#   '288',
#   '584',
#   '51.52',
#   '7487',
#   '0'],
#  ['122',
#   '122',
#   datetime.datetime(2018, 4, 1, 2, 5, 32),
#   '881',
#   '1424',
#   '1.59',
#   '7532',
#   '0'],
#  ['123',
#   '123',
#   datetime.datetime(2018, 4, 1, 2, 5, 51),
#   '410',
#   '860',
#   '34.29',
#   '7551',
#   '0'],
#  ['124',
#   '124',
#   datetime.datetime(2018, 4, 1, 2, 6, 1),
#   '746',
#   '1338',
#   '48.81',
#   '7561',
#   '0'],
#  ['125',
#   '125',
#   datetime.datetime(2018, 4, 1, 2, 7, 2),
#   '99',
#   '80',
#   '35.25',
#   '7622',
#   '0'],
#  ['126',
#   '126',
#   datetime.datetime(2018, 4, 1, 2, 7, 19),
#   '322',
#   '133',
#   '52.82',
#   '7639',
#   '0'],
#  ['127',
#   '127',
#   datetime.datetime(2018, 4, 1, 2, 7, 20),
#   '389',
#   '1971',
#   '50.23',
#   '7640',
#   '0'],
#  ['128',
#   '128',
#   datetime.datetime(2018, 4, 1, 2, 8, 34),
#   '76',
#   '995',
#   '49.14',
#   '7714',
#   '0'],
#  ['129',
#   '129',
#   datetime.datetime(2018, 4, 1, 2, 9, 28),
#   '254',
#   '512',
#   '87.65',
#   '7768',
#   '0'],
#  ['130',
#   '130',
#   datetime.datetime(2018, 4, 1, 2, 10, 45),
#   '774',
#   '1425',
#   '18.81',
#   '7845',
#   '0'],
#  ['131',
#   '131',
#   datetime.datetime(2018, 4, 1, 2, 12, 41),
#   '107',
#   '1521',
#   '49.28',
#   '7961',
#   '0'],
#  ['132',
#   '132',
#   datetime.datetime(2018, 4, 1, 2, 13, 3),
#   '743',
#   '1463',
#   '25.34',
#   '7983',
#   '0'],
#  ['133',
#   '133',
#   datetime.datetime(2018, 4, 1, 2, 13, 15),
#   '321',
#   '1624',
#   '72.96',
#   '7995',
#   '0'],
#  ['134',
#   '134',
#   datetime.datetime(2018, 4, 1, 2, 14, 16),
#   '363',
#   '430',
#   '93.37',
#   '8056',
#   '0'],
#  ['135',
#   '135',
#   datetime.datetime(2018, 4, 1, 2, 14, 52),
#   '820',
#   '80',
#   '5.82',
#   '8092',
#   '0'],
#  ['136',
#   '136',
#   datetime.datetime(2018, 4, 1, 2, 15, 14),
#   '735',
#   '1048',
#   '17.26',
#   '8114',
#   '0'],
#  ['137',
#   '137',
#   datetime.datetime(2018, 4, 1, 2, 15, 24),
#   '544',
#   '462',
#   '59.38',
#   '8124',
#   '0'],
#  ['138',
#   '138',
#   datetime.datetime(2018, 4, 1, 2, 15, 32),
#   '846',
#   '1401',
#   '46.98',
#   '8132',
#   '0'],
#  ['139',
#   '139',
#   datetime.datetime(2018, 4, 1, 2, 15, 46),
#   '672',
#   '576',
#   '138.08',
#   '8146',
#   '0'],
#  ['140',
#   '140',
#   datetime.datetime(2018, 4, 1, 2, 16, 14),
#   '331',
#   '202',
#   '90.57',
#   '8174',
#   '0'],
#  ['141',
#   '141',
#   datetime.datetime(2018, 4, 1, 2, 16, 23),
#   '888',
#   '1453',
#   '40.4',
#   '8183',
#   '0'],
#  ['142',
#   '142',
#   datetime.datetime(2018, 4, 1, 2, 18, 56),
#   '721',
#   '1913',
#   '117.52',
#   '8336',
#   '0'],
#  ['143',
#   '143',
#   datetime.datetime(2018, 4, 1, 2, 19, 19),
#   '746',
#   '1831',
#   '55.55',
#   '8359',
#   '0'],
#  ['144',
#   '144',
#   datetime.datetime(2018, 4, 1, 2, 20, 28),
#   '423',
#   '788',
#   '39.78',
#   '8428',
#   '0'],
#  ['145',
#   '145',
#   datetime.datetime(2018, 4, 1, 2, 21, 38),
#   '521',
#   '1397',
#   '47.11',
#   '8498',
#   '0'],
#  ['146',
#   '146',
#   datetime.datetime(2018, 4, 1, 2, 22, 40),
#   '123',
#   '1239',
#   '29.54',
#   '8560',
#   '0'],
#  ['147',
#   '147',
#   datetime.datetime(2018, 4, 1, 2, 23, 46),
#   '699',
#   '1954',
#   '35.29',
#   '8626',
#   '0'],
#  ['148',
#   '148',
#   datetime.datetime(2018, 4, 1, 2, 23, 53),
#   '183',
#   '1191',
#   '68.47',
#   '8633',
#   '0'],
#  ['149',
#   '149',
#   datetime.datetime(2018, 4, 1, 2, 24, 41),
#   '302',
#   '1378',
#   '136.97',
#   '8681',
#   '0'],
#  ['150',
#   '150',
#   datetime.datetime(2018, 4, 1, 2, 25, 21),
#   '169',
#   '69',
#   '25.03',
#   '8721',
#   '0'],
#  ['151',
#   '151',
#   datetime.datetime(2018, 4, 1, 2, 26, 2),
#   '403',
#   '585',
#   '81.03',
#   '8762',
#   '0'],
#  ['152',
#   '152',
#   datetime.datetime(2018, 4, 1, 2, 26, 38),
#   '574',
#   '578',
#   '25.6',
#   '8798',
#   '0'],
#  ['153',
#   '153',
#   datetime.datetime(2018, 4, 1, 2, 26, 41),
#   '788',
#   '991',
#   '60.68',
#   '8801',
#   '0'],
#  ['154',
#   '154',
#   datetime.datetime(2018, 4, 1, 2, 27, 1),
#   '899',
#   '422',
#   '19.41',
#   '8821',
#   '0'],
#  ['155',
#   '155',
#   datetime.datetime(2018, 4, 1, 2, 27, 13),
#   '869',
#   '1794',
#   '41.76',
#   '8833',
#   '0'],
#  ['156',
#   '156',
#   datetime.datetime(2018, 4, 1, 2, 27, 50),
#   '127',
#   '685',
#   '69.77',
#   '8870',
#   '0'],
#  ['157',
#   '157',
#   datetime.datetime(2018, 4, 1, 2, 28, 26),
#   '161',
#   '1707',
#   '122.92',
#   '8906',
#   '0'],
#  ['158',
#   '158',
#   datetime.datetime(2018, 4, 1, 2, 29, 14),
#   '102',
#   '581',
#   '74.39',
#   '8954',
#   '0'],
#  ['159',
#   '159',
#   datetime.datetime(2018, 4, 1, 2, 29, 24),
#   '560',
#   '713',
#   '16.11',
#   '8964',
#   '0'],
#  ['160',
#   '160',
#   datetime.datetime(2018, 4, 1, 2, 29, 48),
#   '614',
#   '1588',
#   '39.74',
#   '8988',
#   '0'],
#  ['161',
#   '161',
#   datetime.datetime(2018, 4, 1, 2, 29, 55),
#   '289',
#   '1995',
#   '41.55',
#   '8995',
#   '0'],
#  ['162',
#   '162',
#   datetime.datetime(2018, 4, 1, 2, 30, 32),
#   '478',
#   '921',
#   '9.16',
#   '9032',
#   '0'],
#  ['163',
#   '163',
#   datetime.datetime(2018, 4, 1, 2, 30, 34),
#   '186',
#   '334',
#   '15.22',
#   '9034',
#   '0'],
#  ['164',
#   '164',
#   datetime.datetime(2018, 4, 1, 2, 31, 18),
#   '746',
#   '1810',
#   '28.32',
#   '9078',
#   '0'],
#  ['165',
#   '165',
#   datetime.datetime(2018, 4, 1, 2, 32, 1),
#   '170',
#   '1828',
#   '71.8',
#   '9121',
#   '0'],
#  ['166',
#   '166',
#   datetime.datetime(2018, 4, 1, 2, 33, 8),
#   '167',
#   '94',
#   '28.07',
#   '9188',
#   '0'],
#  ['167',
#   '167',
#   datetime.datetime(2018, 4, 1, 2, 33, 23),
#   '264',
#   '262',
#   '48.3',
#   '9203',
#   '0'],
#  ['168',
#   '168',
#   datetime.datetime(2018, 4, 1, 2, 33, 28),
#   '417',
#   '1707',
#   '80.65',
#   '9208',
#   '0'],
#  ['169',
#   '169',
#   datetime.datetime(2018, 4, 1, 2, 34, 10),
#   '739',
#   '746',
#   '66.21',
#   '9250',
#   '0'],
#  ['170',
#   '170',
#   datetime.datetime(2018, 4, 1, 2, 34, 11),
#   '421',
#   '1061',
#   '40.06',
#   '9251',
#   '0'],
#  ['171',
#   '171',
#   datetime.datetime(2018, 4, 1, 2, 34, 12),
#   '606',
#   '270',
#   '29.02',
#   '9252',
#   '0'],
#  ['172',
#   '172',
#   datetime.datetime(2018, 4, 1, 2, 34, 17),
#   '159',
#   '1318',
#   '26.76',
#   '9257',
#   '0'],
#  ['173',
#   '173',
#   datetime.datetime(2018, 4, 1, 2, 34, 40),
#   '250',
#   '659',
#   '125.49',
#   '9280',
#   '0'],
#  ['174',
#   '174',
#   datetime.datetime(2018, 4, 1, 2, 35, 26),
#   '8',
#   '1351',
#   '7.54',
#   '9326',
#   '0'],
#  ['175',
#   '175',
#   datetime.datetime(2018, 4, 1, 2, 38, 22),
#   '659',
#   '1457',
#   '5.69',
#   '9502',
#   '0'],
#  ['176',
#   '176',
#   datetime.datetime(2018, 4, 1, 2, 38, 41),
#   '715',
#   '976',
#   '15.22',
#   '9521',
#   '0'],
#  ['177',
#   '177',
#   datetime.datetime(2018, 4, 1, 2, 39, 3),
#   '728',
#   '1034',
#   '32.48',
#   '9543',
#   '0'],
#  ['178',
#   '178',
#   datetime.datetime(2018, 4, 1, 2, 40, 41),
#   '578',
#   '244',
#   '105.19',
#   '9641',
#   '0'],
#  ['179',
#   '179',
#   datetime.datetime(2018, 4, 1, 2, 42, 45),
#   '620',
#   '394',
#   '152.28',
#   '9765',
#   '0'],
#  ['180',
#   '180',
#   datetime.datetime(2018, 4, 1, 2, 43, 7),
#   '661',
#   '1887',
#   '50.59',
#   '9787',
#   '0'],
#  ['181',
#   '181',
#   datetime.datetime(2018, 4, 1, 2, 43, 34),
#   '59',
#   '543',
#   '124.86',
#   '9814',
#   '0'],
#  ['182',
#   '182',
#   datetime.datetime(2018, 4, 1, 2, 44, 11),
#   '580',
#   '187',
#   '117.22',
#   '9851',
#   '0'],
#  ['183',
#   '183',
#   datetime.datetime(2018, 4, 1, 2, 44, 40),
#   '72',
#   '6',
#   '27.36',
#   '9880',
#   '0'],
#  ['184',
#   '184',
#   datetime.datetime(2018, 4, 1, 2, 45, 24),
#   '379',
#   '1702',
#   '8.25',
#   '9924',
#   '0'],
#  ['185',
#   '185',
#   datetime.datetime(2018, 4, 1, 2, 45, 33),
#   '464',
#   '1882',
#   '71.84',
#   '9933',
#   '0'],
#  ['186',
#   '186',
#   datetime.datetime(2018, 4, 1, 2, 45, 47),
#   '356',
#   '1093',
#   '16.74',
#   '9947',
#   '0'],
#  ['187',
#   '187',
#   datetime.datetime(2018, 4, 1, 2, 45, 47),
#   '146',
#   '1883',
#   '44.02',
#   '9947',
#   '0'],
#  ['188',
#   '188',
#   datetime.datetime(2018, 4, 1, 2, 46, 37),
#   '278',
#   '331',
#   '114.47',
#   '9997',
#   '0'],
#  ['189',
#   '189',
#   datetime.datetime(2018, 4, 1, 2, 47, 17),
#   '146',
#   '1231',
#   '26.78',
#   '10037',
#   '0'],
#  ['190',
#   '190',
#   datetime.datetime(2018, 4, 1, 2, 48, 38),
#   '765',
#   '47',
#   '50.56',
#   '10118',
#   '0'],
#  ['191',
#   '191',
#   datetime.datetime(2018, 4, 1, 2, 49, 28),
#   '560',
#   '713',
#   '33.79',
#   '10168',
#   '0'],
#  ['192',
#   '192',
#   datetime.datetime(2018, 4, 1, 2, 49, 46),
#   '468',
#   '435',
#   '4.01',
#   '10186',
#   '0'],
#  ['193',
#   '193',
#   datetime.datetime(2018, 4, 1, 2, 52, 46),
#   '60',
#   '1763',
#   '3.91',
#   '10366',
#   '0'],
#  ['194',
#   '194',
#   datetime.datetime(2018, 4, 1, 2, 54, 34),
#   '735',
#   '1805',
#   '69.9',
#   '10474',
#   '0'],
#  ['195',
#   '195',
#   datetime.datetime(2018, 4, 1, 2, 55, 6),
#   '119',
#   '447',
#   '47.39',
#   '10506',
#   '0'],
#  ['196',
#   '196',
#   datetime.datetime(2018, 4, 1, 2, 55, 9),
#   '609',
#   '1044',
#   '12.17',
#   '10509',
#   '0'],
#  ['197',
#   '197',
#   datetime.datetime(2018, 4, 1, 2, 56, 14),
#   '517',
#   '1542',
#   '43.28',
#   '10574',
#   '0'],
#  ['198',
#   '198',
#   datetime.datetime(2018, 4, 1, 2, 56, 54),
#   '752',
#   '1438',
#   '106.09',
#   '10614',
#   '0'],
#  ['199',
#   '199',
#   datetime.datetime(2018, 4, 1, 2, 57, 13),
#   '631',
#   '1095',
#   '113.25',
#   '10633',
#   '0'],
#  ['200',
#   '200',
#   datetime.datetime(2018, 4, 1, 2, 57, 28),
#   '3',
#   '263',
#   '94.63',
#   '10648',
#   '0'],
#  ['201',
#   '201',
#   datetime.datetime(2018, 4, 1, 2, 57, 58),
#   '14',
#   '484',
#   '69.49',
#   '10678',
#   '0'],
#  ['202',
#   '202',
#   datetime.datetime(2018, 4, 1, 2, 59, 1),
#   '524',
#   '49',
#   '107.44',
#   '10741',
#   '0'],
#  ['203',
#   '203',
#   datetime.datetime(2018, 4, 1, 2, 59, 24),
#   '197',
#   '1218',
#   '35.77',
#   '10764',
#   '0'],
#  ['204',
#   '204',
#   datetime.datetime(2018, 4, 1, 2, 59, 29),
#   '688',
#   '354',
#   '9.66',
#   '10769',
#   '0'],
#  ['205',
#   '205',
#   datetime.datetime(2018, 4, 1, 2, 59, 30),
#   '182',
#   '595',
#   '15.56',
#   '10770',
#   '0'],
#  ['206',
#   '206',
#   datetime.datetime(2018, 4, 1, 2, 59, 43),
#   '169',
#   '682',
#   '26.4',
#   '10783',
#   '0'],
#  ['207',
#   '207',
#   datetime.datetime(2018, 4, 1, 2, 59, 56),
#   '36',
#   '1175',
#   '33.37',
#   '10796',
#   '0'],
#  ['208',
#   '208',
#   datetime.datetime(2018, 4, 1, 3, 0, 10),
#   '849',
#   '230',
#   '14.08',
#   '10810',
#   '0'],
#  ['209',
#   '209',
#   datetime.datetime(2018, 4, 1, 3, 0, 24),
#   '161',
#   '1719',
#   '105.75',
#   '10824',
#   '0'],
#  ['210',
#   '210',
#   datetime.datetime(2018, 4, 1, 3, 0, 49),
#   '764',
#   '548',
#   '120.15',
#   '10849',
#   '0'],
#  ['211',
#   '211',
#   datetime.datetime(2018, 4, 1, 3, 1, 32),
#   '406',
#   '259',
#   '14.43',
#   '10892',
#   '0'],
#  ['212',
#   '212',
#   datetime.datetime(2018, 4, 1, 3, 4, 39),
#   '887',
#   '27',
#   '35.43',
#   '11079',
#   '0'],
#  ['213',
#   '213',
#   datetime.datetime(2018, 4, 1, 3, 4, 51),
#   '842',
#   '1629',
#   '32.06',
#   '11091',
#   '0'],
#  ['214',
#   '214',
#   datetime.datetime(2018, 4, 1, 3, 5, 43),
#   '18',
#   '1154',
#   '99.17',
#   '11143',
#   '0'],
#  ['215',
#   '215',
#   datetime.datetime(2018, 4, 1, 3, 6, 5),
#   '1',
#   '1836',
#   '25.21',
#   '11165',
#   '0'],
#  ['216',
#   '216',
#   datetime.datetime(2018, 4, 1, 3, 6, 43),
#   '884',
#   '1305',
#   '22.25',
#   '11203',
#   '0'],
#  ['217',
#   '217',
#   datetime.datetime(2018, 4, 1, 3, 7, 8),
#   '101',
#   '79',
#   '36.77',
#   '11228',
#   '0'],
#  ['218',
#   '218',
#   datetime.datetime(2018, 4, 1, 3, 7, 24),
#   '423',
#   '1133',
#   '48.06',
#   '11244',
#   '0'],
#  ['219',
#   '219',
#   datetime.datetime(2018, 4, 1, 3, 8, 25),
#   '283',
#   '946',
#   '31.73',
#   '11305',
#   '0'],
#  ['220',
#   '220',
#   datetime.datetime(2018, 4, 1, 3, 8, 54),
#   '204',
#   '542',
#   '117.56',
#   '11334',
#   '0'],
#  ['221',
#   '221',
#   datetime.datetime(2018, 4, 1, 3, 9, 49),
#   '261',
#   '522',
#   '99.18',
#   '11389',
#   '0'],
#  ['222',
#   '222',
#   datetime.datetime(2018, 4, 1, 3, 9, 59),
#   '768',
#   '806',
#   '87.67',
#   '11399',
#   '0'],
#  ['223',
#   '223',
#   datetime.datetime(2018, 4, 1, 3, 10, 29),
#   '265',
#   '1142',
#   '3.61',
#   '11429',
#   '0'],
#  ['224',
#   '224',
#   datetime.datetime(2018, 4, 1, 3, 10, 50),
#   '237',
#   '1367',
#   '140.43',
#   '11450',
#   '0'],
#  ['225',
#   '225',
#   datetime.datetime(2018, 4, 1, 3, 11, 5),
#   '94',
#   '202',
#   '38.48',
#   '11465',
#   '0'],
#  ['226',
#   '226',
#   datetime.datetime(2018, 4, 1, 3, 11, 6),
#   '601',
#   '926',
#   '28.95',
#   '11466',
#   '0'],
#  ['227',
#   '227',
#   datetime.datetime(2018, 4, 1, 3, 11, 16),
#   '119',
#   '1907',
#   '39.55',
#   '11476',
#   '0'],
#  ['228',
#   '228',
#   datetime.datetime(2018, 4, 1, 3, 12, 9),
#   '316',
#   '130',
#   '109.38',
#   '11529',
#   '0'],
#  ['229',
#   '229',
#   datetime.datetime(2018, 4, 1, 3, 12, 36),
#   '733',
#   '605',
#   '42.8',
#   '11556',
#   '0'],
#  ['230',
#   '230',
#   datetime.datetime(2018, 4, 1, 3, 12, 49),
#   '210',
#   '1032',
#   '4.7',
#   '11569',
#   '0'],
#  ['231',
#   '231',
#   datetime.datetime(2018, 4, 1, 3, 13, 3),
#   '215',
#   '639',
#   '94.98',
#   '11583',
#   '0'],
#  ['232',
#   '232',
#   datetime.datetime(2018, 4, 1, 3, 14, 37),
#   '812',
#   '199',
#   '3.37',
#   '11677',
#   '0'],
#  ['233',
#   '233',
#   datetime.datetime(2018, 4, 1, 3, 16),
#   '501',
#   '180',
#   '52.84',
#   '11760',
#   '0'],
#  ['234',
#   '234',
#   datetime.datetime(2018, 4, 1, 3, 16, 14),
#   '392',
#   '1382',
#   '41.26',
#   '11774',
#   '0'],
#  ['235',
#   '235',
#   datetime.datetime(2018, 4, 1, 3, 17, 18),
#   '39',
#   '1296',
#   '11.42',
#   '11838',
#   '0'],
#  ['236',
#   '236',
#   datetime.datetime(2018, 4, 1, 3, 17, 28),
#   '97',
#   '737',
#   '78.82',
#   '11848',
#   '0'],
#  ['237',
#   '237',
#   datetime.datetime(2018, 4, 1, 3, 19),
#   '492',
#   '1738',
#   '157.03',
#   '11940',
#   '0'],
#  ['238',
#   '238',
#   datetime.datetime(2018, 4, 1, 3, 19, 40),
#   '895',
#   '1332',
#   '39.3',
#   '11980',
#   '0'],
#  ['239',
#   '239',
#   datetime.datetime(2018, 4, 1, 3, 20, 24),
#   '666',
#   '810',
#   '52.08',
#   '12024',
#   '0'],
#  ['240',
#   '240',
#   datetime.datetime(2018, 4, 1, 3, 20, 39),
#   '95',
#   '587',
#   '133.0',
#   '12039',
#   '0'],
#  ['241',
#   '241',
#   datetime.datetime(2018, 4, 1, 3, 21, 58),
#   '888',
#   '1132',
#   '17.79',
#   '12118',
#   '0'],
#  ['242',
#   '242',
#   datetime.datetime(2018, 4, 1, 3, 23, 9),
#   '776',
#   '268',
#   '83.51',
#   '12189',
#   '0'],
#  ['243',
#   '243',
#   datetime.datetime(2018, 4, 1, 3, 23, 42),
#   '555',
#   '1221',
#   '23.59',
#   '12222',
#   '0'],
#  ['244',
#   '244',
#   datetime.datetime(2018, 4, 1, 3, 23, 49),
#   '24',
#   '701',
#   '33.06',
#   '12229',
#   '0'],
#  ['245',
#   '245',
#   datetime.datetime(2018, 4, 1, 3, 24, 24),
#   '27',
#   '547',
#   '100.32',
#   '12264',
#   '0'],
#  ['246',
#   '246',
#   datetime.datetime(2018, 4, 1, 3, 25, 5),
#   '499',
#   '1070',
#   '24.59',
#   '12305',
#   '0'],
#  ['247',
#   '247',
#   datetime.datetime(2018, 4, 1, 3, 25, 10),
#   '745',
#   '186',
#   '15.84',
#   '12310',
#   '0'],
#  ['248',
#   '248',
#   datetime.datetime(2018, 4, 1, 3, 26, 1),
#   '713',
#   '1232',
#   '32.93',
#   '12361',
#   '0'],
#  ['249',
#   '249',
#   datetime.datetime(2018, 4, 1, 3, 26, 5),
#   '233',
#   '1787',
#   '61.43',
#   '12365',
#   '0'],
#  ['250',
#   '250',
#   datetime.datetime(2018, 4, 1, 3, 26, 19),
#   '420',
#   '1498',
#   '20.75',
#   '12379',
#   '0'],
#  ['251',
#   '251',
#   datetime.datetime(2018, 4, 1, 3, 26, 22),
#   '846',
#   '1401',
#   '36.02',
#   '12382',
#   '0'],
#  ['252',
#   '252',
#   datetime.datetime(2018, 4, 1, 3, 27, 37),
#   '443',
#   '1848',
#   '8.81',
#   '12457',
#   '0'],
#  ['253',
#   '253',
#   datetime.datetime(2018, 4, 1, 3, 27, 56),
#   '124',
#   '11',
#   '52.01',
#   '12476',
#   '0'],
#  ['254',
#   '254',
#   datetime.datetime(2018, 4, 1, 3, 28, 15),
#   '33',
#   '1282',
#   '53.14',
#   '12495',
#   '0'],
#  ['255',
#   '255',
#   datetime.datetime(2018, 4, 1, 3, 29, 19),
#   '268',
#   '1002',
#   '27.66',
#   '12559',
#   '0'],
#  ['256',
#   '256',
#   datetime.datetime(2018, 4, 1, 3, 29, 27),
#   '283',
#   '250',
#   '24.39',
#   '12567',
#   '0'],
#  ['257',
#   '257',
#   datetime.datetime(2018, 4, 1, 3, 31, 19),
#   '141',
#   '64',
#   '6.38',
#   '12679',
#   '0'],
#  ['258',
#   '258',
#   datetime.datetime(2018, 4, 1, 3, 31, 53),
#   '146',
#   '1956',
#   '40.16',
#   '12713',
#   '0'],
#  ['259',
#   '259',
#   datetime.datetime(2018, 4, 1, 3, 31, 58),
#   '176',
#   '1703',
#   '94.65',
#   '12718',
#   '0'],
#  ['260',
#   '260',
#   datetime.datetime(2018, 4, 1, 3, 32, 25),
#   '595',
#   '1150',
#   '31.82',
#   '12745',
#   '0'],
#  ['261',
#   '261',
#   datetime.datetime(2018, 4, 1, 3, 32, 51),
#   '41',
#   '201',
#   '43.02',
#   '12771',
#   '0'],
#  ['262',
#   '262',
#   datetime.datetime(2018, 4, 1, 3, 33, 45),
#   '110',
#   '1610',
#   '32.21',
#   '12825',
#   '0'],
#  ['263',
#   '263',
#   datetime.datetime(2018, 4, 1, 3, 34, 19),
#   '522',
#   '480',
#   '52.83',
#   '12859',
#   '0'],
#  ['264',
#   '264',
#   datetime.datetime(2018, 4, 1, 3, 34, 31),
#   '867',
#   '1068',
#   '34.17',
#   '12871',
#   '0'],
#  ['265',
#   '265',
#   datetime.datetime(2018, 4, 1, 3, 35, 11),
#   '345',
#   '1829',
#   '22.65',
#   '12911',
#   '0'],
#  ['266',
#   '266',
#   datetime.datetime(2018, 4, 1, 3, 36, 15),
#   '540',
#   '750',
#   '118.93',
#   '12975',
#   '0'],
#  ['267',
#   '267',
#   datetime.datetime(2018, 4, 1, 3, 36, 52),
#   '480',
#   '1063',
#   '40.86',
#   '13012',
#   '0'],
#  ['268',
#   '268',
#   datetime.datetime(2018, 4, 1, 3, 37, 4),
#   '364',
#   '703',
#   '112.76',
#   '13024',
#   '0'],
#  ['269',
#   '269',
#   datetime.datetime(2018, 4, 1, 3, 38, 5),
#   '680',
#   '467',
#   '15.69',
#   '13085',
#   '0'],
#  ['270',
#   '270',
#   datetime.datetime(2018, 4, 1, 3, 38, 19),
#   '440',
#   '1137',
#   '84.07',
#   '13099',
#   '0'],
#  ['271',
#   '271',
#   datetime.datetime(2018, 4, 1, 3, 38, 20),
#   '804',
#   '849',
#   '12.16',
#   '13100',
#   '0'],
#  ['272',
#   '272',
#   datetime.datetime(2018, 4, 1, 3, 38, 25),
#   '715',
#   '188',
#   '14.63',
#   '13105',
#   '0'],
#  ['273',
#   '273',
#   datetime.datetime(2018, 4, 1, 3, 38, 45),
#   '587',
#   '18',
#   '75.76',
#   '13125',
#   '0'],
#  ['274',
#   '274',
#   datetime.datetime(2018, 4, 1, 3, 39, 14),
#   '325',
#   '170',
#   '84.82',
#   '13154',
#   '0'],
#  ['275',
#   '275',
#   datetime.datetime(2018, 4, 1, 3, 39, 30),
#   '90',
#   '1286',
#   '2.58',
#   '13170',
#   '0'],
#  ['276',
#   '276',
#   datetime.datetime(2018, 4, 1, 3, 39, 36),
#   '14',
#   '1494',
#   '69.05',
#   '13176',
#   '0'],
#  ['277',
#   '277',
#   datetime.datetime(2018, 4, 1, 3, 39, 50),
#   '536',
#   '680',
#   '13.59',
#   '13190',
#   '0'],
#  ['278',
#   '278',
#   datetime.datetime(2018, 4, 1, 3, 39, 59),
#   '376',
#   '1542',
#   '9.25',
#   '13199',
#   '0'],
#  ['279',
#   '279',
#   datetime.datetime(2018, 4, 1, 3, 40, 23),
#   '354',
#   '103',
#   '87.91',
#   '13223',
#   '0'],
#  ['280',
#   '280',
#   datetime.datetime(2018, 4, 1, 3, 40, 31),
#   '724',
#   '884',
#   '10.03',
#   '13231',
#   '0'],
#  ['281',
#   '281',
#   datetime.datetime(2018, 4, 1, 3, 41, 12),
#   '891',
#   '1578',
#   '90.11',
#   '13272',
#   '0'],
#  ['282',
#   '282',
#   datetime.datetime(2018, 4, 1, 3, 41, 29),
#   '428',
#   '169',
#   '56.05',
#   '13289',
#   '0'],
#  ['283',
#   '283',
#   datetime.datetime(2018, 4, 1, 3, 41, 42),
#   '791',
#   '1076',
#   '40.72',
#   '13302',
#   '0'],
#  ['284',
#   '284',
#   datetime.datetime(2018, 4, 1, 3, 43, 47),
#   '180',
#   '1817',
#   '17.52',
#   '13427',
#   '0'],
#  ['285',
#   '285',
#   datetime.datetime(2018, 4, 1, 3, 44, 17),
#   '233',
#   '1835',
#   '95.13',
#   '13457',
#   '0'],
#  ['286',
#   '286',
#   datetime.datetime(2018, 4, 1, 3, 44, 19),
#   '111',
#   '1378',
#   '49.64',
#   '13459',
#   '0'],
#  ['287',
#   '287',
#   datetime.datetime(2018, 4, 1, 3, 44, 44),
#   '197',
#   '1537',
#   '45.98',
#   '13484',
#   '0'],
#  ['288',
#   '288',
#   datetime.datetime(2018, 4, 1, 3, 45, 2),
#   '647',
#   '1219',
#   '113.08',
#   '13502',
#   '0'],
#  ['289',
#   '289',
#   datetime.datetime(2018, 4, 1, 3, 45, 12),
#   '620',
#   '1043',
#   '99.36',
#   '13512',
#   '0'],
#  ['290',
#   '290',
#   datetime.datetime(2018, 4, 1, 3, 45, 35),
#   '753',
#   '335',
#   '26.06',
#   '13535',
#   '0'],
#  ['291',
#   '291',
#   datetime.datetime(2018, 4, 1, 3, 46, 10),
#   '725',
#   '1080',
#   '69.47',
#   '13570',
#   '0'],
#  ['292',
#   '292',
#   datetime.datetime(2018, 4, 1, 3, 47, 15),
#   '355',
#   '1319',
#   '7.42',
#   '13635',
#   '0'],
#  ['293',
#   '293',
#   datetime.datetime(2018, 4, 1, 3, 47, 50),
#   '83',
#   '1833',
#   '16.36',
#   '13670',
#   '0'],
#  ['294',
#   '294',
#   datetime.datetime(2018, 4, 1, 3, 48, 32),
#   '650',
#   '1582',
#   '56.67',
#   '13712',
#   '0'],
#  ['295',
#   '295',
#   datetime.datetime(2018, 4, 1, 3, 48, 36),
#   '605',
#   '35',
#   '3.34',
#   '13716',
#   '0'],
#  ['296',
#   '296',
#   datetime.datetime(2018, 4, 1, 3, 48, 41),
#   '623',
#   '323',
#   '120.04',
#   '13721',
#   '0'],
#  ['297',
#   '297',
#   datetime.datetime(2018, 4, 1, 3, 48, 46),
#   '725',
#   '1080',
#   '83.14',
#   '13726',
#   '0'],
#  ['298',
#   '298',
#   datetime.datetime(2018, 4, 1, 3, 48, 53),
#   '45',
#   '1559',
#   '133.09',
#   '13733',
#   '0'],
#  ['299',
#   '299',
#   datetime.datetime(2018, 4, 1, 3, 49, 9),
#   '540',
#   '973',
#   '107.84',
#   '13749',
#   '0'],
#  ['300',
#   '300',
#   datetime.datetime(2018, 4, 1, 3, 49, 20),
#   '418',
#   '47',
#   '130.21',
#   '13760',
#   '0'],
#  ['301',
#   '301',
#   datetime.datetime(2018, 4, 1, 3, 50, 22),
#   '180',
#   '703',
#   '7.82',
#   '13822',
#   '0'],
#  ['302',
#   '302',
#   datetime.datetime(2018, 4, 1, 3, 50, 38),
#   '180',
#   '1817',
#   '15.84',
#   '13838',
#   '0'],
#  ['303',
#   '303',
#   datetime.datetime(2018, 4, 1, 3, 50, 54),
#   '72',
#   '833',
#   '64.07',
#   '13854',
#   '0'],
#  ['304',
#   '304',
#   datetime.datetime(2018, 4, 1, 3, 51, 12),
#   '150',
#   '398',
#   '40.21',
#   '13872',
#   '0'],
#  ['305',
#   '305',
#   datetime.datetime(2018, 4, 1, 3, 51, 20),
#   '648',
#   '1294',
#   '100.61',
#   '13880',
#   '0'],
#  ['306',
#   '306',
#   datetime.datetime(2018, 4, 1, 3, 51, 48),
#   '3',
#   '1978',
#   '69.41',
#   '13908',
#   '0'],
#  ['307',
#   '307',
#   datetime.datetime(2018, 4, 1, 3, 52, 1),
#   '373',
#   '1035',
#   '84.41',
#   '13921',
#   '0'],
#  ['308',
#   '308',
#   datetime.datetime(2018, 4, 1, 3, 52, 17),
#   '168',
#   '862',
#   '69.88',
#   '13937',
#   '0'],
#  ['309',
#   '309',
#   datetime.datetime(2018, 4, 1, 3, 52, 20),
#   '324',
#   '508',
#   '83.55',
#   '13940',
#   '0'],
#  ['310',
#   '310',
#   datetime.datetime(2018, 4, 1, 3, 52, 28),
#   '793',
#   '178',
#   '9.13',
#   '13948',
#   '0'],
#  ['311',
#   '311',
#   datetime.datetime(2018, 4, 1, 3, 52, 40),
#   '406',
#   '845',
#   '9.78',
#   '13960',
#   '0'],
#  ['312',
#   '312',
#   datetime.datetime(2018, 4, 1, 3, 53, 18),
#   '524',
#   '49',
#   '71.31',
#   '13998',
#   '0'],
#  ['313',
#   '313',
#   datetime.datetime(2018, 4, 1, 3, 53, 47),
#   '278',
#   '78',
#   '127.42',
#   '14027',
#   '0'],
#  ['314',
#   '314',
#   datetime.datetime(2018, 4, 1, 3, 53, 59),
#   '707',
#   '471',
#   '34.26',
#   '14039',
#   '0'],
#  ['315',
#   '315',
#   datetime.datetime(2018, 4, 1, 3, 54, 15),
#   '134',
#   '1713',
#   '21.19',
#   '14055',
#   '0'],
#  ['316',
#   '316',
#   datetime.datetime(2018, 4, 1, 3, 54, 58),
#   '531',
#   '1770',
#   '136.86',
#   '14098',
#   '0'],
#  ['317',
#   '317',
#   datetime.datetime(2018, 4, 1, 3, 55, 30),
#   '685',
#   '1588',
#   '74.31',
#   '14130',
#   '0'],
#  ['318',
#   '318',
#   datetime.datetime(2018, 4, 1, 3, 55, 53),
#   '732',
#   '433',
#   '55.86',
#   '14153',
#   '0'],
#  ['319',
#   '319',
#   datetime.datetime(2018, 4, 1, 3, 56, 8),
#   '420',
#   '825',
#   '93.12',
#   '14168',
#   '0'],
#  ['320',
#   '320',
#   datetime.datetime(2018, 4, 1, 3, 56, 20),
#   '205',
#   '1369',
#   '55.25',
#   '14180',
#   '0'],
#  ['321',
#   '321',
#   datetime.datetime(2018, 4, 1, 3, 56, 21),
#   '200',
#   '1427',
#   '141.45',
#   '14181',
#   '0'],
#  ['322',
#   '322',
#   datetime.datetime(2018, 4, 1, 3, 56, 24),
#   '68',
#   '153',
#   '5.68',
#   '14184',
#   '0'],
#  ['323',
#   '323',
#   datetime.datetime(2018, 4, 1, 3, 57),
#   '581',
#   '1673',
#   '60.41',
#   '14220',
#   '0'],
#  ['324',
#   '324',
#   datetime.datetime(2018, 4, 1, 3, 57, 10),
#   '392',
#   '1408',
#   '25.81',
#   '14230',
#   '0'],
#  ['325',
#   '325',
#   datetime.datetime(2018, 4, 1, 3, 57, 20),
#   '291',
#   '538',
#   '153.2',
#   '14240',
#   '0'],
#  ['326',
#   '326',
#   datetime.datetime(2018, 4, 1, 3, 58, 37),
#   '425',
#   '1859',
#   '13.82',
#   '14317',
#   '0'],
#  ['327',
#   '327',
#   datetime.datetime(2018, 4, 1, 3, 58, 41),
#   '426',
#   '1560',
#   '91.15',
#   '14321',
#   '0'],
#  ['328',
#   '328',
#   datetime.datetime(2018, 4, 1, 3, 58, 43),
#   '650',
#   '559',
#   '56.47',
#   '14323',
#   '0'],
#  ['329',
#   '329',
#   datetime.datetime(2018, 4, 1, 3, 58, 47),
#   '884',
#   '1223',
#   '10.38',
#   '14327',
#   '0'],
#  ['330',
#   '330',
#   datetime.datetime(2018, 4, 1, 3, 58, 51),
#   '73',
#   '674',
#   '115.44',
#   '14331',
#   '0'],
#  ['331',
#   '331',
#   datetime.datetime(2018, 4, 1, 3, 59, 7),
#   '278',
#   '1499',
#   '51.76',
#   '14347',
#   '0'],
#  ['332',
#   '332',
#   datetime.datetime(2018, 4, 1, 3, 59, 34),
#   '493',
#   '729',
#   '111.26',
#   '14374',
#   '0'],
#  ['333',
#   '333',
#   datetime.datetime(2018, 4, 1, 3, 59, 58),
#   '776',
#   '922',
#   '101.69',
#   '14398',
#   '0'],
#  ['334',
#   '334',
#   datetime.datetime(2018, 4, 1, 4, 0, 14),
#   '725',
#   '543',
#   '59.13',
#   '14414',
#   '0'],
#  ['335',
#   '335',
#   datetime.datetime(2018, 4, 1, 4, 0, 55),
#   '440',
#   '1814',
#   '41.67',
#   '14455',
#   '0'],
#  ['336',
#   '336',
#   datetime.datetime(2018, 4, 1, 4, 1, 27),
#   '899',
#   '386',
#   '59.43',
#   '14487',
#   '0'],
#  ['337',
#   '337',
#   datetime.datetime(2018, 4, 1, 4, 2, 28),
#   '142',
#   '557',
#   '41.25',
#   '14548',
#   '0'],
#  ['338',
#   '338',
#   datetime.datetime(2018, 4, 1, 4, 3, 9),
#   '361',
#   '814',
#   '28.63',
#   '14589',
#   '0'],
#  ['339',
#   '339',
#   datetime.datetime(2018, 4, 1, 4, 3, 13),
#   '403',
#   '1880',
#   '5.64',
#   '14593',
#   '0'],
#  ['340',
#   '340',
#   datetime.datetime(2018, 4, 1, 4, 3, 35),
#   '615',
#   '147',
#   '35.9',
#   '14615',
#   '0'],
#  ['341',
#   '341',
#   datetime.datetime(2018, 4, 1, 4, 3, 49),
#   '749',
#   '88',
#   '110.41',
#   '14629',
#   '0'],
#  ['342',
#   '342',
#   datetime.datetime(2018, 4, 1, 4, 4, 23),
#   '728',
#   '436',
#   '81.22',
#   '14663',
#   '0'],
#  ['343',
#   '343',
#   datetime.datetime(2018, 4, 1, 4, 4, 38),
#   '528',
#   '54',
#   '31.61',
#   '14678',
#   '0'],
#  ['344',
#   '344',
#   datetime.datetime(2018, 4, 1, 4, 4, 56),
#   '830',
#   '94',
#   '18.65',
#   '14696',
#   '0'],
#  ['345',
#   '345',
#   datetime.datetime(2018, 4, 1, 4, 5, 8),
#   '300',
#   '623',
#   '28.78',
#   '14708',
#   '0'],
#  ['346',
#   '346',
#   datetime.datetime(2018, 4, 1, 4, 5, 19),
#   '803',
#   '728',
#   '145.04',
#   '14719',
#   '0'],
#  ['347',
#   '347',
#   datetime.datetime(2018, 4, 1, 4, 6, 48),
#   '467',
#   '1536',
#   '10.31',
#   '14808',
#   '0'],
#  ['348',
#   '348',
#   datetime.datetime(2018, 4, 1, 4, 6, 50),
#   '408',
#   '1427',
#   '94.51',
#   '14810',
#   '0'],
#  ['349',
#   '349',
#   datetime.datetime(2018, 4, 1, 4, 7, 46),
#   '496',
#   '1424',
#   '106.69',
#   '14866',
#   '0'],
#  ['350',
#   '350',
#   datetime.datetime(2018, 4, 1, 4, 7, 49),
#   '653',
#   '1734',
#   '59.66',
#   '14869',
#   '0'],
#  ['351',
#   '351',
#   datetime.datetime(2018, 4, 1, 4, 8, 3),
#   '650',
#   '167',
#   '98.73',
#   '14883',
#   '0'],
#  ['352',
#   '352',
#   datetime.datetime(2018, 4, 1, 4, 8, 45),
#   '679',
#   '1125',
#   '138.87',
#   '14925',
#   '0'],
#  ['353',
#   '353',
#   datetime.datetime(2018, 4, 1, 4, 8, 49),
#   '565',
#   '1477',
#   '102.34',
#   '14929',
#   '0'],
#  ['354',
#   '354',
#   datetime.datetime(2018, 4, 1, 4, 8, 53),
#   '500',
#   '318',
#   '55.14',
#   '14933',
#   '0'],
#  ['355',
#   '355',
#   datetime.datetime(2018, 4, 1, 4, 8, 56),
#   '431',
#   '49',
#   '42.46',
#   '14936',
#   '0'],
#  ['356',
#   '356',
#   datetime.datetime(2018, 4, 1, 4, 9, 45),
#   '328',
#   '577',
#   '41.36',
#   '14985',
#   '0'],
#  ['357',
#   '357',
#   datetime.datetime(2018, 4, 1, 4, 9, 50),
#   '863',
#   '242',
#   '13.49',
#   '14990',
#   '0'],
#  ['358',
#   '358',
#   datetime.datetime(2018, 4, 1, 4, 10, 21),
#   '850',
#   '280',
#   '12.34',
#   '15021',
#   '0'],
#  ['359',
#   '359',
#   datetime.datetime(2018, 4, 1, 4, 10, 25),
#   '403',
#   '1183',
#   '85.83',
#   '15025',
#   '0'],
#  ['360',
#   '360',
#   datetime.datetime(2018, 4, 1, 4, 10, 58),
#   '131',
#   '570',
#   '41.03',
#   '15058',
#   '0'],
#  ['361',
#   '361',
#   datetime.datetime(2018, 4, 1, 4, 12, 2),
#   '109',
#   '201',
#   '50.63',
#   '15122',
#   '0'],
#  ['362',
#   '362',
#   datetime.datetime(2018, 4, 1, 4, 12, 6),
#   '233',
#   '1936',
#   '131.11',
#   '15126',
#   '0'],
#  ['363',
#   '363',
#   datetime.datetime(2018, 4, 1, 4, 12, 32),
#   '478',
#   '1688',
#   '35.53',
#   '15152',
#   '0'],
#  ['364',
#   '364',
#   datetime.datetime(2018, 4, 1, 4, 12, 33),
#   '769',
#   '1835',
#   '8.8',
#   '15153',
#   '0'],
#  ['365',
#   '365',
#   datetime.datetime(2018, 4, 1, 4, 12, 38),
#   '209',
#   '762',
#   '49.7',
#   '15158',
#   '0'],
#  ['366',
#   '366',
#   datetime.datetime(2018, 4, 1, 4, 13, 32),
#   '325',
#   '494',
#   '126.55',
#   '15212',
#   '0'],
#  ['367',
#   '367',
#   datetime.datetime(2018, 4, 1, 4, 13, 42),
#   '775',
#   '1701',
#   '60.91',
#   '15222',
#   '0'],
#  ['368',
#   '368',
#   datetime.datetime(2018, 4, 1, 4, 14, 8),
#   '440',
#   '1037',
#   '61.42',
#   '15248',
#   '0'],
#  ['369',
#   '369',
#   datetime.datetime(2018, 4, 1, 4, 15, 12),
#   '415',
#   '479',
#   '59.76',
#   '15312',
#   '0'],
#  ['370',
#   '370',
#   datetime.datetime(2018, 4, 1, 4, 15, 37),
#   '898',
#   '1467',
#   '22.33',
#   '15337',
#   '0'],
#  ['371',
#   '371',
#   datetime.datetime(2018, 4, 1, 4, 15, 45),
#   '733',
#   '1611',
#   '50.12',
#   '15345',
#   '0'],
#  ['372',
#   '372',
#   datetime.datetime(2018, 4, 1, 4, 15, 46),
#   '749',
#   '88',
#   '138.32',
#   '15346',
#   '0'],
#  ['373',
#   '373',
#   datetime.datetime(2018, 4, 1, 4, 16, 17),
#   '406',
#   '1922',
#   '27.73',
#   '15377',
#   '0'],
#  ['374',
#   '374',
#   datetime.datetime(2018, 4, 1, 4, 16, 33),
#   '216',
#   '336',
#   '75.79',
#   '15393',
#   '0'],
#  ['375',
#   '375',
#   datetime.datetime(2018, 4, 1, 4, 17, 3),
#   '418',
#   '464',
#   '113.5',
#   '15423',
#   '0'],
#  ['376',
#   '376',
#   datetime.datetime(2018, 4, 1, 4, 17, 13),
#   '268',
#   '1002',
#   '10.17',
#   '15433',
#   '0'],
#  ['377',
#   '377',
#   datetime.datetime(2018, 4, 1, 4, 17, 19),
#   '476',
#   '1749',
#   '12.23',
#   '15439',
#   '0'],
#  ['378',
#   '378',
#   datetime.datetime(2018, 4, 1, 4, 18, 16),
#   '120',
#   '1177',
#   '19.27',
#   '15496',
#   '0'],
#  ['379',
#   '379',
#   datetime.datetime(2018, 4, 1, 4, 18, 34),
#   '356',
#   '1676',
#   '19.4',
#   '15514',
#   '0'],
#  ['380',
#   '380',
#   datetime.datetime(2018, 4, 1, 4, 19, 2),
#   '138',
#   '1404',
#   '45.23',
#   '15542',
#   '0'],
#  ['381',
#   '381',
#   datetime.datetime(2018, 4, 1, 4, 19, 21),
#   '328',
#   '418',
#   '45.29',
#   '15561',
#   '0'],
#  ['382',
#   '382',
#   datetime.datetime(2018, 4, 1, 4, 19, 36),
#   '487',
#   '1849',
#   '17.11',
#   '15576',
#   '0'],
#  ['383',
#   '383',
#   datetime.datetime(2018, 4, 1, 4, 19, 37),
#   '533',
#   '1739',
#   '145.2',
#   '15577',
#   '0'],
#  ['384',
#   '384',
#   datetime.datetime(2018, 4, 1, 4, 20, 15),
#   '305',
#   '1513',
#   '93.03',
#   '15615',
#   '0'],
#  ['385',
#   '385',
#   datetime.datetime(2018, 4, 1, 4, 20, 23),
#   '275',
#   '649',
#   '27.22',
#   '15623',
#   '0'],
#  ['386',
#   '386',
#   datetime.datetime(2018, 4, 1, 4, 20, 28),
#   '264',
#   '1608',
#   '10.61',
#   '15628',
#   '0'],
#  ['387',
#   '387',
#   datetime.datetime(2018, 4, 1, 4, 20, 43),
#   '833',
#   '73',
#   '24.92',
#   '15643',
#   '0'],
#  ['388',
#   '388',
#   datetime.datetime(2018, 4, 1, 4, 20, 55),
#   '154',
#   '1540',
#   '6.52',
#   '15655',
#   '0'],
#  ['389',
#   '389',
#   datetime.datetime(2018, 4, 1, 4, 20, 58),
#   '48',
#   '1698',
#   '2.88',
#   '15658',
#   '0'],
#  ['390',
#   '390',
#   datetime.datetime(2018, 4, 1, 4, 21, 2),
#   '887',
#   '443',
#   '21.13',
#   '15662',
#   '0'],
#  ['391',
#   '391',
#   datetime.datetime(2018, 4, 1, 4, 21, 22),
#   '150',
#   '1099',
#   '107.78',
#   '15682',
#   '0'],
#  ['392',
#   '392',
#   datetime.datetime(2018, 4, 1, 4, 21, 25),
#   '828',
#   '1748',
#   '40.0',
#   '15685',
#   '0'],
#  ['393',
#   '393',
#   datetime.datetime(2018, 4, 1, 4, 21, 44),
#   '166',
#   '1214',
#   '58.44',
#   '15704',
#   '0'],
#  ['394',
#   '394',
#   datetime.datetime(2018, 4, 1, 4, 21, 45),
#   '814',
#   '530',
#   '45.71',
#   '15705',
#   '0'],
#  ['395',
#   '395',
#   datetime.datetime(2018, 4, 1, 4, 21, 55),
#   '320',
#   '1689',
#   '73.12',
#   '15715',
#   '0'],
#  ['396',
#   '396',
#   datetime.datetime(2018, 4, 1, 4, 22, 3),
#   '410',
#   '785',
#   '43.2',
#   '15723',
#   '0'],
#  ['397',
#   '397',
#   datetime.datetime(2018, 4, 1, 4, 22, 55),
#   '370',
#   '1479',
#   '64.85',
#   '15775',
#   '0'],
#  ['398',
#   '398',
#   datetime.datetime(2018, 4, 1, 4, 23, 34),
#   '127',
#   '609',
#   '84.76',
#   '15814',
#   '0'],
#  ['399',
#   '399',
#   datetime.datetime(2018, 4, 1, 4, 23, 53),
#   '691',
#   '382',
#   '89.21',
#   '15833',
#   '0'],
#  ['400',
#   '400',
#   datetime.datetime(2018, 4, 1, 4, 24, 7),
#   '890',
#   '1237',
#   '26.51',
#   '15847',
#   '0'],
#  ['401',
#   '401',
#   datetime.datetime(2018, 4, 1, 4, 24, 9),
#   '388',
#   '702',
#   '95.71',
#   '15849',
#   '0'],
#  ['402',
#   '402',
#   datetime.datetime(2018, 4, 1, 4, 24, 32),
#   '365',
#   '1377',
#   '15.68',
#   '15872',
#   '0'],
#  ['403',
#   '403',
#   datetime.datetime(2018, 4, 1, 4, 24, 50),
#   '487',
#   '1124',
#   '19.79',
#   '15890',
#   '0'],
#  ['404',
#   '404',
#   datetime.datetime(2018, 4, 1, 4, 24, 54),
#   '764',
#   '1509',
#   '13.23',
#   '15894',
#   '0'],
#  ['405',
#   '405',
#   datetime.datetime(2018, 4, 1, 4, 25, 7),
#   '847',
#   '691',
#   '12.01',
#   '15907',
#   '0'],
#  ['406',
#   '406',
#   datetime.datetime(2018, 4, 1, 4, 25, 45),
#   '801',
#   '148',
#   '71.54',
#   '15945',
#   '0'],
#  ['407',
#   '407',
#   datetime.datetime(2018, 4, 1, 4, 26, 8),
#   '67',
#   '1701',
#   '62.79',
#   '15968',
#   '0'],
#  ['408',
#   '408',
#   datetime.datetime(2018, 4, 1, 4, 26, 13),
#   '148',
#   '451',
#   '27.79',
#   '15973',
#   '0'],
#  ['409',
#   '409',
#   datetime.datetime(2018, 4, 1, 4, 26, 43),
#   '526',
#   '109',
#   '47.95',
#   '16003',
#   '0'],
#  ['410',
#   '410',
#   datetime.datetime(2018, 4, 1, 4, 26, 43),
#   '422',
#   '1030',
#   '38.09',
#   '16003',
#   '0'],
#  ['411',
#   '411',
#   datetime.datetime(2018, 4, 1, 4, 27, 22),
#   '897',
#   '1591',
#   '86.42',
#   '16042',
#   '0'],
#  ['412',
#   '412',
#   datetime.datetime(2018, 4, 1, 4, 27, 27),
#   '39',
#   '1821',
#   '14.2',
#   '16047',
#   '0'],
#  ['413',
#   '413',
#   datetime.datetime(2018, 4, 1, 4, 28, 1),
#   '690',
#   '312',
#   '4.77',
#   '16081',
#   '0'],
#  ['414',
#   '414',
#   datetime.datetime(2018, 4, 1, 4, 28, 2),
#   '793',
#   '1642',
#   '11.89',
#   '16082',
#   '0'],
#  ['415',
#   '415',
#   datetime.datetime(2018, 4, 1, 4, 30, 18),
#   '595',
#   '1183',
#   '103.78',
#   '16218',
#   '0'],
#  ['416',
#   '416',
#   datetime.datetime(2018, 4, 1, 4, 30, 27),
#   '316',
#   '519',
#   '78.26',
#   '16227',
#   '0'],
#  ['417',
#   '417',
#   datetime.datetime(2018, 4, 1, 4, 30, 27),
#   '321',
#   '311',
#   '39.44',
#   '16227',
#   '0'],
#  ['418',
#   '418',
#   datetime.datetime(2018, 4, 1, 4, 30, 29),
#   '699',
#   '430',
#   '9.51',
#   '16229',
#   '0'],
#  ['419',
#   '419',
#   datetime.datetime(2018, 4, 1, 4, 30, 50),
#   '51',
#   '1661',
#   '139.72',
#   '16250',
#   '0'],
#  ['420',
#   '420',
#   datetime.datetime(2018, 4, 1, 4, 31, 7),
#   '480',
#   '1320',
#   '25.45',
#   '16267',
#   '0'],
#  ['421',
#   '421',
#   datetime.datetime(2018, 4, 1, 4, 31, 51),
#   '449',
#   '499',
#   '73.72',
#   '16311',
#   '0'],
#  ['422',
#   '422',
#   datetime.datetime(2018, 4, 1, 4, 32, 11),
#   '330',
#   '1712',
#   '64.19',
#   '16331',
#   '0'],
#  ['423',
#   '423',
#   datetime.datetime(2018, 4, 1, 4, 32, 20),
#   '491',
#   '305',
#   '12.59',
#   '16340',
#   '0'],
#  ['424',
#   '424',
#   datetime.datetime(2018, 4, 1, 4, 33, 45),
#   '175',
#   '979',
#   '123.28',
#   '16425',
#   '0'],
#  ['425',
#   '425',
#   datetime.datetime(2018, 4, 1, 4, 33, 59),
#   '124',
#   '354',
#   '177.52',
#   '16439',
#   '0'],
#  ['426',
#   '426',
#   datetime.datetime(2018, 4, 1, 4, 34, 12),
#   '178',
#   '937',
#   '25.21',
#   '16452',
#   '0'],
#  ['427',
#   '427',
#   datetime.datetime(2018, 4, 1, 4, 34, 16),
#   '27',
#   '547',
#   '87.75',
#   '16456',
#   '0'],
#  ['428',
#   '428',
#   datetime.datetime(2018, 4, 1, 4, 34, 27),
#   '438',
#   '561',
#   '102.29',
#   '16467',
#   '0'],
#  ['429',
#   '429',
#   datetime.datetime(2018, 4, 1, 4, 34, 54),
#   '27',
#   '84',
#   '71.65',
#   '16494',
#   '0'],
#  ['430',
#   '430',
#   datetime.datetime(2018, 4, 1, 4, 34, 54),
#   '322',
#   '751',
#   '49.67',
#   '16494',
#   '0'],
#  ['431',
#   '431',
#   datetime.datetime(2018, 4, 1, 4, 35, 8),
#   '686',
#   '50',
#   '96.25',
#   '16508',
#   '0'],
#  ['432',
#   '432',
#   datetime.datetime(2018, 4, 1, 4, 36, 31),
#   '815',
#   '1062',
#   '4.65',
#   '16591',
#   '0'],
#  ['433',
#   '433',
#   datetime.datetime(2018, 4, 1, 4, 37, 3),
#   '69',
#   '239',
#   '56.14',
#   '16623',
#   '0'],
#  ['434',
#   '434',
#   datetime.datetime(2018, 4, 1, 4, 37, 37),
#   '821',
#   '607',
#   '29.46',
#   '16657',
#   '0'],
#  ['435',
#   '435',
#   datetime.datetime(2018, 4, 1, 4, 37, 46),
#   '241',
#   '546',
#   '19.81',
#   '16666',
#   '0'],
#  ['436',
#   '436',
#   datetime.datetime(2018, 4, 1, 4, 38, 9),
#   '693',
#   '1335',
#   '32.68',
#   '16689',
#   '0'],
#  ['437',
#   '437',
#   datetime.datetime(2018, 4, 1, 4, 38, 37),
#   '177',
#   '766',
#   '16.28',
#   '16717',
#   '0'],
#  ['438',
#   '438',
#   datetime.datetime(2018, 4, 1, 4, 39, 8),
#   '715',
#   '1645',
#   '26.51',
#   '16748',
#   '0'],
#  ['439',
#   '439',
#   datetime.datetime(2018, 4, 1, 4, 40, 2),
#   '175',
#   '612',
#   '71.08',
#   '16802',
#   '0'],
#  ['440',
#   '440',
# ...
#   '119',
#   '1563',
#   '74.94',
#   '23424',
#   '0'],
#  ['855',
#   '855',
#   datetime.datetime(2018, 4, 1, 6, 30, 51),
#   '717',
#   '600',
#   '6.74',
#   '23451',
#   '0'],
#  ['856',
#   '856',
#   datetime.datetime(2018, 4, 1, 6, 30, 55),
#   '824',
#   '1877',
#   '16.49',
#   '23455',
#   '0'],
#  ['857',
#   '857',
#   datetime.datetime(2018, 4, 1, 6, 31, 18),
#   '788',
#   '79',
#   '63.33',
#   '23478',
#   '0'],
#  ['858',
#   '858',
#   datetime.datetime(2018, 4, 1, 6, 31, 49),
#   '484',
#   '391',
#   '29.45',
#   '23509',
#   '0'],
#  ['859',
#   '859',
#   datetime.datetime(2018, 4, 1, 6, 31, 58),
#   '132',
#   '1951',
#   '46.4',
#   '23518',
#   '0'],
#  ['860',
#   '860',
#   datetime.datetime(2018, 4, 1, 6, 32, 43),
#   '381',
#   '1456',
#   '79.68',
#   '23563',
#   '0'],
#  ['861',
#   '861',
#   datetime.datetime(2018, 4, 1, 6, 33, 6),
#   '793',
#   '899',
#   '12.52',
#   '23586',
#   '0'],
#  ['862',
#   '862',
#   datetime.datetime(2018, 4, 1, 6, 33, 28),
#   '894',
#   '815',
#   '89.91',
#   '23608',
#   '0'],
#  ['863',
#   '863',
#   datetime.datetime(2018, 4, 1, 6, 34, 13),
#   '110',
#   '1084',
#   '10.08',
#   '23653',
#   '0'],
#  ['864',
#   '864',
#   datetime.datetime(2018, 4, 1, 6, 34, 22),
#   '746',
#   '1338',
#   '51.45',
#   '23662',
#   '0'],
#  ['865',
#   '865',
#   datetime.datetime(2018, 4, 1, 6, 34, 23),
#   '285',
#   '1135',
#   '73.81',
#   '23663',
#   '0'],
#  ['866',
#   '866',
#   datetime.datetime(2018, 4, 1, 6, 34, 32),
#   '614',
#   '1588',
#   '28.43',
#   '23672',
#   '0'],
#  ['867',
#   '867',
#   datetime.datetime(2018, 4, 1, 6, 34, 45),
#   '182',
#   '1340',
#   '12.53',
#   '23685',
#   '0'],
#  ['868',
#   '868',
#   datetime.datetime(2018, 4, 1, 6, 34, 53),
#   '167',
#   '819',
#   '29.73',
#   '23693',
#   '0'],
#  ['869',
#   '869',
#   datetime.datetime(2018, 4, 1, 6, 34, 54),
#   '865',
#   '894',
#   '6.75',
#   '23694',
#   '0'],
#  ['870',
#   '870',
#   datetime.datetime(2018, 4, 1, 6, 34, 57),
#   '284',
#   '507',
#   '41.83',
#   '23697',
#   '0'],
#  ['871',
#   '871',
#   datetime.datetime(2018, 4, 1, 6, 35, 21),
#   '743',
#   '1357',
#   '44.92',
#   '23721',
#   '0'],
#  ['872',
#   '872',
#   datetime.datetime(2018, 4, 1, 6, 35, 31),
#   '278',
#   '1740',
#   '106.14',
#   '23731',
#   '0'],
#  ['873',
#   '873',
#   datetime.datetime(2018, 4, 1, 6, 35, 48),
#   '74',
#   '1291',
#   '64.64',
#   '23748',
#   '0'],
#  ['874',
#   '874',
#   datetime.datetime(2018, 4, 1, 6, 35, 51),
#   '295',
#   '891',
#   '51.99',
#   '23751',
#   '0'],
#  ['875',
#   '875',
#   datetime.datetime(2018, 4, 1, 6, 35, 58),
#   '83',
#   '1772',
#   '23.36',
#   '23758',
#   '0'],
#  ['876',
#   '876',
#   datetime.datetime(2018, 4, 1, 6, 36, 16),
#   '298',
#   '1710',
#   '123.25',
#   '23776',
#   '0'],
#  ['877',
#   '877',
#   datetime.datetime(2018, 4, 1, 6, 36, 22),
#   '39',
#   '1296',
#   '16.02',
#   '23782',
#   '0'],
#  ['878',
#   '878',
#   datetime.datetime(2018, 4, 1, 6, 36, 35),
#   '854',
#   '1821',
#   '5.29',
#   '23795',
#   '0'],
#  ['879',
#   '879',
#   datetime.datetime(2018, 4, 1, 6, 36, 57),
#   '58',
#   '1747',
#   '5.98',
#   '23817',
#   '0'],
#  ['880',
#   '880',
#   datetime.datetime(2018, 4, 1, 6, 37),
#   '310',
#   '945',
#   '44.57',
#   '23820',
#   '0'],
#  ['881',
#   '881',
#   datetime.datetime(2018, 4, 1, 6, 37, 20),
#   '896',
#   '318',
#   '59.68',
#   '23840',
#   '0'],
#  ['882',
#   '882',
#   datetime.datetime(2018, 4, 1, 6, 37, 41),
#   '372',
#   '595',
#   '57.27',
#   '23861',
#   '0'],
#  ['883',
#   '883',
#   datetime.datetime(2018, 4, 1, 6, 38, 5),
#   '856',
#   '1574',
#   '58.7',
#   '23885',
#   '0'],
#  ['884',
#   '884',
#   datetime.datetime(2018, 4, 1, 6, 39, 3),
#   '492',
#   '190',
#   '59.95',
#   '23943',
#   '0'],
#  ['885',
#   '885',
#   datetime.datetime(2018, 4, 1, 6, 39, 12),
#   '233',
#   '1936',
#   '33.81',
#   '23952',
#   '0'],
#  ['886',
#   '886',
#   datetime.datetime(2018, 4, 1, 6, 39, 34),
#   '585',
#   '529',
#   '11.8',
#   '23974',
#   '0'],
#  ['887',
#   '887',
#   datetime.datetime(2018, 4, 1, 6, 39, 34),
#   '237',
#   '1081',
#   '69.74',
#   '23974',
#   '0'],
#  ['888',
#   '888',
#   datetime.datetime(2018, 4, 1, 6, 40, 29),
#   '681',
#   '1217',
#   '0.9',
#   '24029',
#   '0'],
#  ['889',
#   '889',
#   datetime.datetime(2018, 4, 1, 6, 40, 37),
#   '131',
#   '83',
#   '54.72',
#   '24037',
#   '0'],
#  ['890',
#   '890',
#   datetime.datetime(2018, 4, 1, 6, 40, 42),
#   '615',
#   '148',
#   '15.09',
#   '24042',
#   '0'],
#  ['891',
#   '891',
#   datetime.datetime(2018, 4, 1, 6, 41, 2),
#   '25',
#   '1608',
#   '60.19',
#   '24062',
#   '0'],
#  ['892',
#   '892',
#   datetime.datetime(2018, 4, 1, 6, 41, 17),
#   '675',
#   '1405',
#   '121.4',
#   '24077',
#   '0'],
#  ['893',
#   '893',
#   datetime.datetime(2018, 4, 1, 6, 41, 27),
#   '728',
#   '436',
#   '113.2',
#   '24087',
#   '0'],
#  ['894',
#   '894',
#   datetime.datetime(2018, 4, 1, 6, 41, 36),
#   '131',
#   '570',
#   '100.17',
#   '24096',
#   '0'],
#  ['895',
#   '895',
#   datetime.datetime(2018, 4, 1, 6, 42, 7),
#   '614',
#   '1958',
#   '40.47',
#   '24127',
#   '0'],
#  ['896',
#   '896',
#   datetime.datetime(2018, 4, 1, 6, 42, 15),
#   '724',
#   '201',
#   '10.24',
#   '24135',
#   '0'],
#  ['897',
#   '897',
#   datetime.datetime(2018, 4, 1, 6, 42, 17),
#   '257',
#   '1275',
#   '11.43',
#   '24137',
#   '0'],
#  ['898',
#   '898',
#   datetime.datetime(2018, 4, 1, 6, 42, 32),
#   '397',
#   '1905',
#   '54.95',
#   '24152',
#   '0'],
#  ['899',
#   '899',
#   datetime.datetime(2018, 4, 1, 6, 43, 9),
#   '172',
#   '721',
#   '57.81',
#   '24189',
#   '0'],
#  ['900',
#   '900',
#   datetime.datetime(2018, 4, 1, 6, 43, 11),
#   '20',
#   '1033',
#   '168.82',
#   '24191',
#   '0'],
#  ['901',
#   '901',
#   datetime.datetime(2018, 4, 1, 6, 43, 50),
#   '531',
#   '1463',
#   '111.72',
#   '24230',
#   '0'],
#  ['902',
#   '902',
#   datetime.datetime(2018, 4, 1, 6, 44, 8),
#   '531',
#   '508',
#   '102.76',
#   '24248',
#   '0'],
#  ['903',
#   '903',
#   datetime.datetime(2018, 4, 1, 6, 44, 18),
#   '298',
#   '1710',
#   '35.47',
#   '24258',
#   '0'],
#  ['904',
#   '904',
#   datetime.datetime(2018, 4, 1, 6, 44, 24),
#   '125',
#   '1279',
#   '42.93',
#   '24264',
#   '0'],
#  ['905',
#   '905',
#   datetime.datetime(2018, 4, 1, 6, 44, 25),
#   '776',
#   '33',
#   '85.22',
#   '24265',
#   '0'],
#  ['906',
#   '906',
#   datetime.datetime(2018, 4, 1, 6, 44, 33),
#   '158',
#   '1821',
#   '13.09',
#   '24273',
#   '0'],
#  ['907',
#   '907',
#   datetime.datetime(2018, 4, 1, 6, 44, 49),
#   '429',
#   '1248',
#   '128.76',
#   '24289',
#   '0'],
#  ['908',
#   '908',
#   datetime.datetime(2018, 4, 1, 6, 45, 3),
#   '249',
#   '983',
#   '137.65',
#   '24303',
#   '0'],
#  ['909',
#   '909',
#   datetime.datetime(2018, 4, 1, 6, 45, 9),
#   '244',
#   '708',
#   '20.07',
#   '24309',
#   '0'],
#  ['910',
#   '910',
#   datetime.datetime(2018, 4, 1, 6, 45, 27),
#   '107',
#   '1175',
#   '54.0',
#   '24327',
#   '0'],
#  ['911',
#   '911',
#   datetime.datetime(2018, 4, 1, 6, 45, 51),
#   '693',
#   '856',
#   '66.19',
#   '24351',
#   '0'],
#  ['912',
#   '912',
#   datetime.datetime(2018, 4, 1, 6, 46),
#   '141',
#   '1479',
#   '12.43',
#   '24360',
#   '0'],
#  ['913',
#   '913',
#   datetime.datetime(2018, 4, 1, 6, 46, 9),
#   '182',
#   '218',
#   '13.05',
#   '24369',
#   '0'],
#  ['914',
#   '914',
#   datetime.datetime(2018, 4, 1, 6, 46, 32),
#   '89',
#   '139',
#   '94.8',
#   '24392',
#   '0'],
#  ['915',
#   '915',
#   datetime.datetime(2018, 4, 1, 6, 46, 42),
#   '344',
#   '1975',
#   '46.67',
#   '24402',
#   '0'],
#  ['916',
#   '916',
#   datetime.datetime(2018, 4, 1, 6, 46, 46),
#   '615',
#   '147',
#   '88.09',
#   '24406',
#   '0'],
#  ['917',
#   '917',
#   datetime.datetime(2018, 4, 1, 6, 46, 54),
#   '444',
#   '252',
#   '41.42',
#   '24414',
#   '0'],
#  ['918',
#   '918',
#   datetime.datetime(2018, 4, 1, 6, 47, 29),
#   '186',
#   '1404',
#   '12.93',
#   '24449',
#   '0'],
#  ['919',
#   '919',
#   datetime.datetime(2018, 4, 1, 6, 47, 29),
#   '788',
#   '480',
#   '56.34',
#   '24449',
#   '0'],
#  ['920',
#   '920',
#   datetime.datetime(2018, 4, 1, 6, 47, 38),
#   '444',
#   '505',
#   '137.79',
#   '24458',
#   '0'],
#  ['921',
#   '921',
#   datetime.datetime(2018, 4, 1, 6, 47, 54),
#   '549',
#   '14',
#   '36.7',
#   '24474',
#   '0'],
#  ['922',
#   '922',
#   datetime.datetime(2018, 4, 1, 6, 48, 48),
#   '793',
#   '358',
#   '13.6',
#   '24528',
#   '0'],
#  ['923',
#   '923',
#   datetime.datetime(2018, 4, 1, 6, 48, 55),
#   '366',
#   '1150',
#   '44.25',
#   '24535',
#   '0'],
#  ['924',
#   '924',
#   datetime.datetime(2018, 4, 1, 6, 49, 24),
#   '789',
#   '1500',
#   '24.64',
#   '24564',
#   '0'],
#  ['925',
#   '925',
#   datetime.datetime(2018, 4, 1, 6, 49, 39),
#   '304',
#   '1921',
#   '86.68',
#   '24579',
#   '0'],
#  ['926',
#   '926',
#   datetime.datetime(2018, 4, 1, 6, 49, 44),
#   '506',
#   '1722',
#   '32.6',
#   '24584',
#   '0'],
#  ['927',
#   '927',
#   datetime.datetime(2018, 4, 1, 6, 49, 52),
#   '327',
#   '936',
#   '99.57',
#   '24592',
#   '0'],
#  ['928',
#   '928',
#   datetime.datetime(2018, 4, 1, 6, 49, 58),
#   '311',
#   '530',
#   '115.33',
#   '24598',
#   '0'],
#  ['929',
#   '929',
#   datetime.datetime(2018, 4, 1, 6, 50, 5),
#   '690',
#   '296',
#   '2.2',
#   '24605',
#   '0'],
#  ['930',
#   '930',
#   datetime.datetime(2018, 4, 1, 6, 50, 8),
#   '302',
#   '98',
#   '46.02',
#   '24608',
#   '0'],
#  ['931',
#   '931',
#   datetime.datetime(2018, 4, 1, 6, 50, 10),
#   '160',
#   '1114',
#   '40.17',
#   '24610',
#   '0'],
#  ['932',
#   '932',
#   datetime.datetime(2018, 4, 1, 6, 50, 18),
#   '59',
#   '161',
#   '173.55',
#   '24618',
#   '0'],
#  ['933',
#   '933',
#   datetime.datetime(2018, 4, 1, 6, 50, 33),
#   '211',
#   '1039',
#   '101.27',
#   '24633',
#   '0'],
#  ['934',
#   '934',
#   datetime.datetime(2018, 4, 1, 6, 50, 42),
#   '559',
#   '1258',
#   '92.08',
#   '24642',
#   '0'],
#  ['935',
#   '935',
#   datetime.datetime(2018, 4, 1, 6, 51),
#   '536',
#   '1870',
#   '20.72',
#   '24660',
#   '0'],
#  ['936',
#   '936',
#   datetime.datetime(2018, 4, 1, 6, 51, 7),
#   '303',
#   '571',
#   '42.27',
#   '24667',
#   '0'],
#  ['937',
#   '937',
#   datetime.datetime(2018, 4, 1, 6, 51, 25),
#   '212',
#   '1942',
#   '10.48',
#   '24685',
#   '0'],
#  ['938',
#   '938',
#   datetime.datetime(2018, 4, 1, 6, 51, 49),
#   '446',
#   '1894',
#   '71.44',
#   '24709',
#   '0'],
#  ['939',
#   '939',
#   datetime.datetime(2018, 4, 1, 6, 52, 19),
#   '117',
#   '869',
#   '16.09',
#   '24739',
#   '0'],
#  ['940',
#   '940',
#   datetime.datetime(2018, 4, 1, 6, 52, 25),
#   '16',
#   '1436',
#   '89.2',
#   '24745',
#   '0'],
#  ['941',
#   '941',
#   datetime.datetime(2018, 4, 1, 6, 52, 28),
#   '646',
#   '754',
#   '106.24',
#   '24748',
#   '0'],
#  ['942',
#   '942',
#   datetime.datetime(2018, 4, 1, 6, 53, 14),
#   '529',
#   '814',
#   '72.37',
#   '24794',
#   '0'],
#  ['943',
#   '943',
#   datetime.datetime(2018, 4, 1, 6, 53, 31),
#   '472',
#   '877',
#   '74.96',
#   '24811',
#   '0'],
#  ['944',
#   '944',
#   datetime.datetime(2018, 4, 1, 6, 53, 34),
#   '86',
#   '755',
#   '49.41',
#   '24814',
#   '0'],
#  ['945',
#   '945',
#   datetime.datetime(2018, 4, 1, 6, 53, 35),
#   '108',
#   '1787',
#   '72.09',
#   '24815',
#   '0'],
#  ['946',
#   '946',
#   datetime.datetime(2018, 4, 1, 6, 53, 47),
#   '331',
#   '43',
#   '101.03',
#   '24827',
#   '0'],
#  ['947',
#   '947',
#   datetime.datetime(2018, 4, 1, 6, 54, 18),
#   '833',
#   '472',
#   '14.26',
#   '24858',
#   '0'],
#  ['948',
#   '948',
#   datetime.datetime(2018, 4, 1, 6, 54, 28),
#   '37',
#   '532',
#   '151.19',
#   '24868',
#   '0'],
#  ['949',
#   '949',
#   datetime.datetime(2018, 4, 1, 6, 54, 59),
#   '340',
#   '1828',
#   '8.25',
#   '24899',
#   '0'],
#  ['950',
#   '950',
#   datetime.datetime(2018, 4, 1, 6, 55, 8),
#   '8',
#   '446',
#   '5.23',
#   '24908',
#   '0'],
#  ['951',
#   '951',
#   datetime.datetime(2018, 4, 1, 6, 55, 31),
#   '896',
#   '757',
#   '67.87',
#   '24931',
#   '0'],
#  ['952',
#   '952',
#   datetime.datetime(2018, 4, 1, 6, 55, 35),
#   '776',
#   '922',
#   '97.41',
#   '24935',
#   '0'],
#  ['953',
#   '953',
#   datetime.datetime(2018, 4, 1, 6, 55, 43),
#   '449',
#   '139',
#   '77.38',
#   '24943',
#   '0'],
#  ['954',
#   '954',
#   datetime.datetime(2018, 4, 1, 6, 55, 45),
#   '735',
#   '653',
#   '60.47',
#   '24945',
#   '0'],
#  ['955',
#   '955',
#   datetime.datetime(2018, 4, 1, 6, 55, 51),
#   '312',
#   '919',
#   '7.71',
#   '24951',
#   '0'],
#  ['956',
#   '956',
#   datetime.datetime(2018, 4, 1, 6, 55, 57),
#   '87',
#   '190',
#   '39.18',
#   '24957',
#   '0'],
#  ['957',
#   '957',
#   datetime.datetime(2018, 4, 1, 6, 56, 15),
#   '407',
#   '569',
#   '125.09',
#   '24975',
#   '0'],
#  ['958',
#   '958',
#   datetime.datetime(2018, 4, 1, 6, 56, 34),
#   '5',
#   '863',
#   '27.56',
#   '24994',
#   '0'],
#  ['959',
#   '959',
#   datetime.datetime(2018, 4, 1, 6, 56, 48),
#   '238',
#   '223',
#   '44.8',
#   '25008',
#   '0'],
#  ['960',
#   '960',
#   datetime.datetime(2018, 4, 1, 6, 56, 55),
#   '5',
#   '1077',
#   '38.43',
#   '25015',
#   '0'],
#  ['961',
#   '961',
#   datetime.datetime(2018, 4, 1, 6, 57),
#   '493',
#   '1505',
#   '43.39',
#   '25020',
#   '0'],
#  ['962',
#   '962',
#   datetime.datetime(2018, 4, 1, 6, 57, 6),
#   '580',
#   '187',
#   '117.57',
#   '25026',
#   '0'],
#  ['963',
#   '963',
#   datetime.datetime(2018, 4, 1, 6, 57, 36),
#   '151',
#   '1143',
#   '49.45',
#   '25056',
#   '0'],
#  ['964',
#   '964',
#   datetime.datetime(2018, 4, 1, 6, 57, 55),
#   '410',
#   '1275',
#   '59.79',
#   '25075',
#   '0'],
#  ['965',
#   '965',
#   datetime.datetime(2018, 4, 1, 6, 58, 5),
#   '253',
#   '699',
#   '57.52',
#   '25085',
#   '0'],
#  ['966',
#   '966',
#   datetime.datetime(2018, 4, 1, 6, 58, 11),
#   '17',
#   '1097',
#   '15.37',
#   '25091',
#   '0'],
#  ['967',
#   '967',
#   datetime.datetime(2018, 4, 1, 6, 58, 22),
#   '893',
#   '1727',
#   '22.65',
#   '25102',
#   '0'],
#  ['968',
#   '968',
#   datetime.datetime(2018, 4, 1, 6, 58, 51),
#   '460',
#   '341',
#   '37.21',
#   '25131',
#   '0'],
#  ['969',
#   '969',
#   datetime.datetime(2018, 4, 1, 7, 0, 1),
#   '382',
#   '32',
#   '26.52',
#   '25201',
#   '0'],
#  ['970',
#   '970',
#   datetime.datetime(2018, 4, 1, 7, 0, 12),
#   '541',
#   '375',
#   '100.26',
#   '25212',
#   '0'],
#  ['971',
#   '971',
#   datetime.datetime(2018, 4, 1, 7, 0, 55),
#   '852',
#   '1355',
#   '41.67',
#   '25255',
#   '0'],
#  ['972',
#   '972',
#   datetime.datetime(2018, 4, 1, 7, 1, 11),
#   '893',
#   '974',
#   '23.53',
#   '25271',
#   '0'],
#  ['973',
#   '973',
#   datetime.datetime(2018, 4, 1, 7, 1, 33),
#   '676',
#   '956',
#   '52.15',
#   '25293',
#   '0'],
#  ['974',
#   '974',
#   datetime.datetime(2018, 4, 1, 7, 1, 39),
#   '679',
#   '993',
#   '86.17',
#   '25299',
#   '0'],
#  ['975',
#   '975',
#   datetime.datetime(2018, 4, 1, 7, 2, 27),
#   '612',
#   '1850',
#   '37.39',
#   '25347',
#   '0'],
#  ['976',
#   '976',
#   datetime.datetime(2018, 4, 1, 7, 2, 43),
#   '53',
#   '291',
#   '9.02',
#   '25363',
#   '0'],
#  ['977',
#   '977',
#   datetime.datetime(2018, 4, 1, 7, 3, 8),
#   '764',
#   '1996',
#   '76.89',
#   '25388',
#   '0'],
#  ['978',
#   '978',
#   datetime.datetime(2018, 4, 1, 7, 3, 29),
#   '371',
#   '1257',
#   '90.66',
#   '25409',
#   '0'],
#  ['979',
#   '979',
#   datetime.datetime(2018, 4, 1, 7, 3, 36),
#   '768',
#   '862',
#   '65.07',
#   '25416',
#   '0'],
#  ['980',
#   '980',
#   datetime.datetime(2018, 4, 1, 7, 3, 38),
#   '629',
#   '38',
#   '116.62',
#   '25418',
#   '0'],
#  ['981',
#   '981',
#   datetime.datetime(2018, 4, 1, 7, 4, 16),
#   '211',
#   '1357',
#   '119.74',
#   '25456',
#   '0'],
#  ['982',
#   '982',
#   datetime.datetime(2018, 4, 1, 7, 4, 35),
#   '196',
#   '1626',
#   '107.18',
#   '25475',
#   '0'],
#  ['983',
#   '983',
#   datetime.datetime(2018, 4, 1, 7, 4, 40),
#   '781',
#   '1781',
#   '110.65',
#   '25480',
#   '0'],
#  ['984',
#   '984',
#   datetime.datetime(2018, 4, 1, 7, 4, 57),
#   '435',
#   '893',
#   '71.71',
#   '25497',
#   '0'],
#  ['985',
#   '985',
#   datetime.datetime(2018, 4, 1, 7, 5),
#   '226',
#   '1535',
#   '38.77',
#   '25500',
#   '0'],
#  ['986',
#   '986',
#   datetime.datetime(2018, 4, 1, 7, 5, 17),
#   '492',
#   '978',
#   '120.18',
#   '25517',
#   '0'],
#  ['987',
#   '987',
#   datetime.datetime(2018, 4, 1, 7, 5, 51),
#   '460',
#   '801',
#   '79.96',
#   '25551',
#   '0'],
#  ['988',
#   '988',
#   datetime.datetime(2018, 4, 1, 7, 6, 28),
#   '103',
#   '1838',
#   '67.83',
#   '25588',
#   '0'],
#  ['989',
#   '989',
#   datetime.datetime(2018, 4, 1, 7, 6, 39),
#   '597',
#   '689',
#   '54.55',
#   '25599',
#   '0'],
#  ['990',
#   '990',
#   datetime.datetime(2018, 4, 1, 7, 7, 14),
#   '666',
#   '980',
#   '44.75',
#   '25634',
#   '0'],
#  ['991',
#   '991',
#   datetime.datetime(2018, 4, 1, 7, 7, 25),
#   '206',
#   '1444',
#   '46.88',
#   '25645',
#   '0'],
#  ['992',
#   '992',
#   datetime.datetime(2018, 4, 1, 7, 8, 4),
#   '115',
#   '1772',
#   '25.86',
#   '25684',
#   '0'],
#  ['993',
#   '993',
#   datetime.datetime(2018, 4, 1, 7, 9, 4),
#   '193',
#   '1489',
#   '5.95',
#   '25744',
#   '0'],
#  ['994',
#   '994',
#   datetime.datetime(2018, 4, 1, 7, 9, 27),
#   '284',
#   '686',
#   '38.33',
#   '25767',
#   '0'],
#  ['995',
#   '995',
#   datetime.datetime(2018, 4, 1, 7, 9, 52),
#   '89',
#   '1820',
#   '28.45',
#   '25792',
#   '0'],
#  ['996',
#   '996',
#   datetime.datetime(2018, 4, 1, 7, 9, 53),
#   '654',
#   '1843',
#   '93.42',
#   '25793',
#   '0'],
#  ['997',
#   '997',
#   datetime.datetime(2018, 4, 1, 7, 10, 52),
#   '27',
#   '547',
#   '75.22',
#   '25852',
#   '0'],
#  ['998',
#   '998',
#   datetime.datetime(2018, 4, 1, 7, 11, 4),
#   '174',
#   '1431',
#   '27.56',
#   '25864',
#   '0'],
#  ['999',
#   '999',
#   datetime.datetime(2018, 4, 1, 7, 11, 5),
#   '699',
#   '430',
#   '61.21',
#   '25865',
#   '0'],
#  ...]
